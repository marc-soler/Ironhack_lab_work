# %% [markdown]
# # Import Libraries and CSV

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import re
import nltk

# %%
df = pd.read_csv('alldata.csv')

# %%
new = df["location"].str.split(", ", n=1,expand = True)
df['city'] = new[0]
df['state'] = new[1].str.split(" ",n=1,expand = True)[0]
df = df.drop(['location', 'reviews', 'company'], axis=1)
df = df.drop_duplicates()
df = df.dropna()
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#                                             position  \
# 0                               Development Director
# 1  An Ostentatiously-Excitable Principal Research...
# 2                                     Data Scientist
# 3                                       Data Analyst
# 4  Assistant Professor -TT - Signal Processing & ...
#
#                                          description     city state
# 0  Development Director\nALS Therapy Development ...  Atlanta    GA
# 1  Job Description\n\n"The road that leads to acc...  Atlanta    GA
# 2  Growing company located in the Atlanta, GA are...  Atlanta    GA
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...  Atlanta    GA
# 4  DESCRIPTION\nThe Emory University Department o...  Atlanta    GA

# %% [markdown]
# # Position

# %% [markdown]
# ## Checking Values

# %%
## cleaning Position values
df['position'] = df['position'].apply(lambda x: re.sub(r'[^\w\s]','', x))
df['position'] = df['position'].apply(lambda x: re.sub(r'\r\n',' ', x))
df['position'] = df['position'].apply(lambda x: re.sub(r'\s+', ' ', x))

## putting all the Position words in the same list
position_check = ""
for job in df['position']:
    position_check += " " + job

## tokenizing
from nltk.tokenize import word_tokenize
all_position_low = position_check.lower()
position_tokens = word_tokenize(str(all_position_low))

df.head()
# Out:
#                                             position  \
# 0                               Development Director
# 1  An OstentatiouslyExcitable Principal Research ...
# 2                                     Data Scientist
# 3                                       Data Analyst
# 4  Assistant Professor TT Signal Processing Machi...
#
#                                          description     city state
# 0  Development Director\nALS Therapy Development ...  Atlanta    GA
# 1  Job Description\n\n"The road that leads to acc...  Atlanta    GA
# 2  Growing company located in the Atlanta, GA are...  Atlanta    GA
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...  Atlanta    GA
# 4  DESCRIPTION\nThe Emory University Department o...  Atlanta    GA

# %% [markdown]
# ## Standardising Position Names

# %%
lower_position = [position.lower() for position in df['position']]
category = []
for position in lower_position:
    if "anal" in position or "database" in position or "research anal" in position:
        category.append('data analyst')
    elif "data scien" in position or "machine learning" in position or "scien" in position:
        category.append('data scientist')
    elif "engineer" in position or "artificial intelligence" in position or "ai" in position or "software" in position:
        category.append('data engineer')
    else:
        category.append('other')
df['position'] = category

# %%
df['position'].value_counts().head(20).sort_values(ascending = True)
# Out:
# data engineer     1011
# data analyst      1227
# other             1656
# data scientist    3014
# Name: position, dtype: int64

# %% [markdown]
# # Description

# %% [markdown]
# ## Checking Values

# %%
## cleaning description values
df['description'] = df['description'].apply(lambda x: re.sub(r'[^\w\s]','', x))
df['description'] = df['description'].apply(lambda x: re.sub(r'\r\n',' ', x))
df['description'] = df['description'].apply(lambda x: re.sub(r'\s+', ' ', x))

# %%
from nltk.tokenize import word_tokenize
descriptions = []
for desc in df['description']:
    desc = desc.lower()
    desc = word_tokenize(str(desc))
    descriptions.append(desc)

df['description'] = descriptions

# %%
matrix = {'data analyst': {},
         'data engineer': {},
         'data scientist': {}}
positions = ['data analyst', 'data engineer', 'data scientist']
tool_list = ['python','sql','java','excel',
               'aws','linux','tableau','sas','oracle',
               'mysql','matlab','html','tensorflow','spss']
skill_list = ['machine learning','data analysis','visualization',
            'modeling','statistical analysis','research','deep learning',
            'optimization','decision tree','logistic','random forest',
            'ab testing','web scraping','neural network','interpersonal skills',
            'communication skills','artificial intelligence']
degree_list = ['master',"masters",'phd','bachelor',"bachelors",
             'high school','No degree requirement']
major_list = ['computer science','data science','statistics','quantitative',
            'mathematics','economics','liberal arts','science','buisness',
            'engineer','engineering','psychology','biology','medicine',
            'marketing','business analysis','chemical engineering','chemistry',
            'public health','public relationship']
var_list_of_lists = [tool_list, skill_list, degree_list, major_list]

for pos in positions:
        for var_list in var_list_of_lists:
            for var in var_list:
                n = 0
                for i in list(df.loc[df['position'] == pos].index):
                    p = df.iloc[i,1]
                    if len(var) == 1:
                        if var in p:
                            n += 1
                    else:
                        if var in ' '.join(str(e) for e in p):
                            n += 1
                matrix[pos].update({var: n})

epic_df = pd.DataFrame.from_dict(matrix, orient='columns')

# %%
epic_df.head(20)
# Out:
#                       data analyst  data engineer  data scientist
# python                         427            478            1678
# sql                            472            324             925
# java                           134            405             693
# excel                          753            467            1353
# aws                            149            287             481
# linux                           48            176             241
# tableau                        203             34             202
# sas                            269             67             397
# oracle                          54             40              73
# mysql                           30             58              64
# matlab                          92             81             317
# html                            29             66              51
# tensorflow                      16             33             340
# spss                            94              2              79
# machine learning               208            317            1686
# data analysis                  307             93             779
# visualization                  242            112             539
# modeling                       304            168             971
# statistical analysis           136             33             338
# research                       785            445            1873

# %%
df_copy.head(50)
# Out:
#           position                                        description  \
# 0            other  [development, director, als, therapy, developm...
# 1   data scientist  [job, description, the, road, that, leads, to,...
# 2   data scientist  [growing, company, located, in, the, atlanta, ...
# 3     data analyst  [department, program, operationsposition, loca...
# 4   data scientist  [description, the, emory, university, departme...
# 5    data engineer  [qualifications, bachelors, degree, in, comput...
# 6            other  [qualifications, bachelors, degree, 57, years,...
# 7   data scientist  [overview, responsibilities, wood, environment...
# 8     data analyst  [works, closely, with, senior, cib, profession...
# 9   data scientist  [known, for, being, a, great, place, to, work,...
# 10    data analyst  [the, statistical, forecast, analyst, position...
# 11  data scientist  [chenega, professional, amp, technical, servic...
# 12  data scientist  [innovate, collaborate, shine, lighthouse, kpm...
# 13  data scientist  [description, under, minimal, supervision, the...
# 14    data analyst  [data, science, analyst, business, intelligenc...
# 15  data scientist  [cotiviti, is, looking, for, an, industry, lea...
# 16   data engineer  [description, executes, complex, assignments, ...
# 17           other  [overview, at, perficient, youll, deliver, mis...
# 18  data scientist  [data, scientist, summary, as, an, amazon, web...
# 19  data scientist  [this, position, is, critical, to, understandi...
# 20   data engineer  [description, burns, amp, mcdonnell, is, consi...
# 21           other  [known, for, being, a, great, place, to, work,...
# 22  data scientist  [join, a, growing, data, science, and, advance...
# 23  data scientist  [position, purpose, a, data, scientist, levera...
# 24  data scientist  [job, number, 16614, position, title, external...
# 25  data scientist  [airsage, has, been, in, the, business, of, pr...
# 26  data scientist  [position, purpose, the, data, scientist, i, w...
# 27  data scientist  [fulltime, permanent, position, available, sta...
# 28  data scientist  [position, purpose, at, homedepotcom, our, awa...
# 29  data scientist  [overview, consultant, the, data, science, amp...
# 30  data scientist  [sr, data, scientist, why, catalina, catalinas...
# 31  data scientist  [data, scientist, business, intelligence, loca...
# 32  data scientist  [kleinfelder, has, been, connecting, great, pe...
# 33    data analyst  [position, description, save, lives, fulfill, ...
# 34  data scientist  [we, are, looking, for, a, data, scientist, wh...
# 35  data scientist  [relayhealth, pharmacy, solutions, rhps, a, mc...
# 36  data scientist  [responsibilitieshelp, to, drive, the, analyti...
# 37  data scientist  [the, purpose, of, this, position, is, to, ide...
# 38  data scientist  [with, demand, sensing, om, partners, is, brea...
# 39  data scientist  [position, purpose, the, data, scientist, spac...
# 40  data scientist  [qualifications, advanced, degree, mba, ms, ph...
# 41  data scientist  [cotiviti, is, looking, for, an, industry, lea...
# 42  data scientist  [manager, orlando, location, overview, the, da...
# 43  data scientist  [the, ideal, candidate, is, a, product, develo...
# 44  data scientist  [join, a, growing, data, science, and, advance...
# 45  data scientist  [join, a, growing, data, science, and, advance...
# 46  data scientist  [consultant, orlando, florida, the, data, scie...
# 47    data analyst  [responsibilities, include, duties, to, suppor...
# 48  data scientist  [we, are, looking, for, talented, driven, and,...
# 49  data scientist  [the, incumbent, will, provide, scientific, co...
#
#        city state  python
# 0   Atlanta    GA     NaN
# 1   Atlanta    GA     NaN
# 2   Atlanta    GA     NaN
# 3   Atlanta    GA     1.0
# 4   Atlanta    GA     NaN
# 5   Atlanta    GA     NaN
# 6   Atlanta    GA     NaN
# 7   Atlanta    GA     NaN
# 8   Atlanta    GA     0.0
# 9   Atlanta    GA     NaN
# 10  Atlanta    GA     0.0
# 11  Atlanta    GA     NaN
# 12  Atlanta    GA     NaN
# 13  Atlanta    GA     NaN
# 14  Atlanta    GA     0.0
# 15  Atlanta    GA     NaN
# 16  Atlanta    GA     NaN
# 17  Atlanta    GA     NaN
# 18  Atlanta    GA     NaN
# 19  Atlanta    GA     NaN
# 20  Atlanta    GA     NaN
# 21  Atlanta    GA     NaN
# 22  Atlanta    GA     NaN
# 23  Atlanta    GA     NaN
# 24  Atlanta    GA     NaN
# 25  Atlanta    GA     NaN
# 26  Atlanta    GA     NaN
# 27  Atlanta    GA     NaN
# 28  Atlanta    GA     NaN
# 29  Atlanta    GA     NaN
# 30  Atlanta    GA     NaN
# 31  Atlanta    GA     NaN
# 32  Atlanta    GA     NaN
# 33  Atlanta    GA     0.0
# 34  Atlanta    GA     NaN
# 35  Atlanta    GA     NaN
# 36  Atlanta    GA     NaN
# 37  Atlanta    GA     NaN
# 38  Atlanta    GA     NaN
# 39  Atlanta    GA     NaN
# 40  Atlanta    GA     NaN
# 41  Atlanta    GA     NaN
# 42  Atlanta    GA     NaN
# 43  Atlanta    GA     NaN
# 44  Atlanta    GA     NaN
# 45  Atlanta    GA     NaN
# 46  Atlanta    GA     NaN
# 47  Atlanta    GA     1.0
# 48  Atlanta    GA     NaN
# 49  Atlanta    GA     NaN

# %% [markdown]
# ## Description by Position - WordCloud

# %%
da = df.loc[df['position'] == "data analyst"]
ds = df.loc[df['position'] == "data scientist"]
de = df.loc[df['position'] == "data engineer"]
ot = df.loc[df['position'] == "other"]

da.head(2)
# Out:
#        position                                        description     city  \
# 3  data analyst  DEPARTMENT Program OperationsPOSITION LOCATION...  Atlanta
# 8  data analyst  Works closely with senior CIB professionals Pe...  Atlanta
#
#   state
# 3    GA
# 8    GA

# %%
ds.head(2)
# Out:
#          position                                        description     city  \
# 1  data scientist  Job Description The road that leads to accompl...  Atlanta
# 2  data scientist  Growing company located in the Atlanta GA area...  Atlanta
#
#   state
# 1    GA
# 2    GA

# %%
de.head(2)
# Out:
#          position                                        description     city  \
# 5   data engineer  Qualifications Bachelors degree in Computer Sc...  Atlanta
# 16  data engineer  Description Executes complex assignments requi...  Atlanta
#
#    state
# 5     GA
# 16    GA

# %%
ot.head(2)
# Out:
#   position                                        description     city state
# 0    other  Development Director ALS Therapy Development I...  Atlanta    GA
# 6    other  Qualifications Bachelors degree 57 years of ex...  Atlanta    GA

# %% [markdown]
# ### Data Analyst

# %%
## merge all the description together in one variable
analyst_descrip = ""
for descrip in da['description']:
    analyst_descrip += " " + descrip

## import english stop_words (I, am, in, the...)
from nltk.corpus import stopwords
extra_stopword = ['data','experience','work','team','will','skill','year','skills']
stop_words1 = set((stopwords.words('english')))
stop_words = stop_words1.union(extra_stopword)

## transform the description in a tokenized list of words
from nltk.tokenize import word_tokenize
analyst_descrip_low= analyst_descrip.lower()
tokens = word_tokenize(str(analyst_descrip_low))

## count the frequency of witch tokenized word (without stop_words)
filtered_descrip_analyst = []
for word in tokens:
    if word not in list(stop_words):
        filtered_descrip_analyst += [word]
        
from collections import Counter
Counter(filtered_descrip_analyst).most_common()
# Out:
# [('research', 3384),
#  ('business', 2514),
#  ('analysis', 2111),
#  ('management', 1819),
#  ('ability', 1727),
#  ('analytics', 1572),
#  ('support', 1395),
#  ('including', 1311),
#  ('new', 1243),
#  ('strong', 1221),
#  ('development', 1219),
#  ('years', 1215),
#  ('required', 1179),
#  ('degree', 1165),
#  ('information', 1140),
#  ('analyst', 1136),
#  ('clients', 1101),
#  ('knowledge', 1098),
#  ('working', 1063),
#  ('position', 975),
#  ('related', 919),
#  ('projects', 895),
#  ('tools', 877),
#  ('analytical', 875),
#  ('financial', 865),
#  ('requirements', 860),
#  ('quantitative', 857),
#  ('provide', 851),
#  ('teams', 832),
#  ('project', 832),
#  ('develop', 810),
#  ('technical', 805),
#  ('amp', 803),
#  ('solutions', 794),
#  ('environment', 792),
#  ('opportunity', 777),
#  ('us', 743),
#  ('status', 737),
#  ('qualifications', 735),
#  ('job', 733),
#  ('communication', 729),
#  ('must', 727),
#  ('across', 727),
#  ('company', 720),
#  ('reports', 711),
#  ('preferred', 709),
#  ('services', 707),
#  ('health', 701),
#  ('statistical', 687),
#  ('insights', 686),
#  ('using', 684),
#  ('systems', 680),
#  ('science', 680),
#  ('responsibilities', 675),
#  ('role', 669),
#  ('reporting', 667),
#  ('product', 664),
#  ('andor', 660),
#  ('technology', 657),
#  ('client', 648),
#  ('help', 648),
#  ('field', 645),
#  ('software', 641),
#  ('design', 641),
#  ('within', 639),
#  ('well', 638),
#  ('market', 636),
#  ('people', 622),
#  ('quality', 620),
#  ('one', 617),
#  ('investment', 615),
#  ('understanding', 615),
#  ('use', 614),
#  ('key', 609),
#  ('marketing', 608),
#  ('performance', 600),
#  ('excellent', 565),
#  ('complex', 560),
#  ('models', 557),
#  ('program', 545),
#  ('employment', 539),
#  ('equal', 538),
#  ('operations', 537),
#  ('industry', 537),
#  ('global', 535),
#  ('time', 533),
#  ('education', 532),
#  ('advanced', 530),
#  ('risk', 523),
#  ('customer', 519),
#  ('organization', 516),
#  ('may', 513),
#  ('responsible', 512),
#  ('needs', 511),
#  ('internal', 511),
#  ('process', 509),
#  ('make', 505),
#  ('policy', 498),
#  ('able', 492),
#  ('products', 489),
#  ('service', 487),
#  ('written', 486),
#  ('national', 478),
#  ('best', 473),
#  ('engineering', 473),
#  ('identify', 471),
#  ('office', 470),
#  ('employer', 469),
#  ('multiple', 461),
#  ('level', 459),
#  ('include', 459),
#  ('scientists', 458),
#  ('professional', 457),
#  ('manage', 453),
#  ('sql', 451),
#  ('processes', 451),
#  ('bachelors', 448),
#  ('strategic', 442),
#  ('opportunities', 441),
#  ('excel', 441),
#  ('analyze', 440),
#  ('also', 439),
#  ('drive', 438),
#  ('ensure', 436),
#  ('relevant', 435),
#  ('build', 435),
#  ('statistics', 432),
#  ('plus', 428),
#  ('apply', 425),
#  ('youll', 425),
#  ('senior', 424),
#  ('staff', 420),
#  ('system', 418),
#  ('please', 418),
#  ('modeling', 417),
#  ('issues', 416),
#  ('developing', 415),
#  ('etc', 414),
#  ('problems', 413),
#  ('maintain', 413),
#  ('minimum', 412),
#  ('intelligence', 411),
#  ('public', 408),
#  ('high', 407),
#  ('finance', 407),
#  ('customers', 403),
#  ('based', 400),
#  ('expertise', 399),
#  ('create', 397),
#  ('strategy', 397),
#  ('candidate', 396),
#  ('results', 392),
#  ('disability', 391),
#  ('analysts', 389),
#  ('gender', 388),
#  ('benefits', 388),
#  ('communicate', 387),
#  ('computer', 384),
#  ('applications', 384),
#  ('programming', 377),
#  ('medical', 376),
#  ('security', 376),
#  ('analyses', 375),
#  ('eg', 374),
#  ('effectively', 373),
#  ('learning', 371),
#  ('programs', 371),
#  ('leadership', 369),
#  ('training', 368),
#  ('employees', 365),
#  ('group', 364),
#  ('model', 364),
#  ('assist', 360),
#  ('r', 359),
#  ('looking', 355),
#  ('applicants', 354),
#  ('perform', 354),
#  ('providing', 354),
#  ('stakeholders', 353),
#  ('members', 352),
#  ('writing', 352),
#  ('database', 350),
#  ('python', 350),
#  ('part', 349),
#  ('world', 348),
#  ('methods', 347),
#  ('appropriate', 345),
#  ('improve', 344),
#  ('external', 344),
#  ('provides', 343),
#  ('join', 341),
#  ('federal', 340),
#  ('large', 338),
#  ('demonstrated', 338),
#  ('social', 338),
#  ('planning', 334),
#  ('application', 333),
#  ('candidates', 332),
#  ('impact', 331),
#  ('deliver', 331),
#  ('areas', 330),
#  ('qualified', 329),
#  ('building', 329),
#  ('value', 329),
#  ('various', 326),
#  ('care', 325),
#  ('recommendations', 324),
#  ('understand', 324),
#  ('highly', 322),
#  ('leading', 322),
#  ('decisions', 321),
#  ('orientation', 319),
#  ('techniques', 317),
#  ('2', 316),
#  ('diverse', 316),
#  ('success', 316),
#  ('managers', 316),
#  ('sales', 312),
#  ('masters', 312),
#  ('activities', 312),
#  ('strategies', 310),
#  ('clinical', 310),
#  ('duties', 309),
#  ('practices', 308),
#  ('growth', 305),
#  ('testing', 304),
#  ('protected', 303),
#  ('lead', 303),
#  ('race', 301),
#  ('color', 299),
#  ('documentation', 298),
#  ('critical', 297),
#  ('digital', 296),
#  ('media', 295),
#  ('variety', 294),
#  ('origin', 293),
#  ('sexual', 293),
#  ('mission', 293),
#  ('meet', 293),
#  ('identity', 292),
#  ('1', 292),
#  ('trends', 291),
#  ('veteran', 290),
#  ('religion', 289),
#  ('partners', 288),
#  ('access', 285),
#  ('competitive', 281),
#  ('microsoft', 280),
#  ('without', 279),
#  ('closely', 278),
#  ('department', 277),
#  ('focus', 276),
#  ('individuals', 275),
#  ('learn', 275),
#  ('manager', 273),
#  ('implementation', 273),
#  ('detail', 270),
#  ('innovative', 270),
#  ('findings', 269),
#  ('individual', 269),
#  ('3', 268),
#  ('sources', 267),
#  ('need', 267),
#  ('conduct', 267),
#  ('consulting', 267),
#  ('successful', 266),
#  ('managing', 264),
#  ('visualization', 263),
#  ('analyzing', 262),
#  ('engineers', 262),
#  ('center', 260),
#  ('markets', 260),
#  ('effective', 259),
#  ('economics', 258),
#  ('sets', 256),
#  ('firm', 256),
#  ('organizational', 254),
#  ('state', 253),
#  ('databases', 252),
#  ('independently', 252),
#  ('tasks', 251),
#  ('life', 251),
#  ('portfolio', 251),
#  ('review', 250),
#  ('problem', 250),
#  ('collaborate', 250),
#  ('operational', 249),
#  ('making', 249),
#  ('primary', 249),
#  ('university', 249),
#  ('action', 246),
#  ('resources', 246),
#  ('background', 245),
#  ('law', 244),
#  ('partner', 244),
#  ('york', 244),
#  ('age', 243),
#  ('verbal', 240),
#  ('healthcare', 240),
#  ('least', 239),
#  ('sex', 238),
#  ('initiatives', 238),
#  ('local', 238),
#  ('analytic', 236),
#  ('following', 235),
#  ('proficiency', 235),
#  ('supporting', 235),
#  ('online', 234),
#  ('committed', 233),
#  ('companies', 232),
#  ('assigned', 231),
#  ('collection', 231),
#  ('requires', 229),
#  ('thinking', 229),
#  ('attention', 228),
#  ('5', 228),
#  ('like', 227),
#  ('every', 227),
#  ('range', 226),
#  ('description', 225),
#  ('functions', 225),
#  ('mathematics', 224),
#  ('capabilities', 224),
#  ('government', 224),
#  ('regard', 223),
#  ('current', 223),
#  ('around', 223),
#  ('decision', 223),
#  ('big', 223),
#  ('user', 222),
#  ('culture', 220),
#  ('equivalent', 219),
#  ('technologies', 219),
#  ('existing', 218),
#  ('presentations', 217),
#  ('basis', 215),
#  ('plans', 215),
#  ('employee', 215),
#  ('standards', 214),
#  ('future', 214),
#  ('solving', 212),
#  ('plan', 211),
#  ('procedures', 210),
#  ('good', 210),
#  ('sas', 209),
#  ('tableau', 209),
#  ('seeking', 209),
#  ('metrics', 209),
#  ('used', 209),
#  ('city', 209),
#  ('relationships', 208),
#  ('levels', 207),
#  ('area', 207),
#  ('platform', 207),
#  ('needed', 207),
#  ('college', 207),
#  ('basic', 206),
#  ('methodologies', 206),
#  ('take', 206),
#  ('specific', 205),
#  ('additional', 205),
#  ('challenges', 205),
#  ('corporate', 204),
#  ('way', 204),
#  ('ideas', 204),
#  ('questions', 204),
#  ('career', 204),
#  ('general', 204),
#  ('policies', 202),
#  ('test', 202),
#  ('credit', 201),
#  ('delivery', 201),
#  ('travel', 201),
#  ('real', 201),
#  ('insurance', 199),
#  ('google', 199),
#  ('member', 197),
#  ('innovation', 197),
#  ('limited', 196),
#  ('interpersonal', 196),
#  ('studies', 195),
#  ('presentation', 194),
#  ('change', 194),
#  ('communications', 193),
#  ('subject', 193),
#  ('implement', 191),
#  ('better', 190),
#  ('worlds', 189),
#  ('community', 189),
#  ('efforts', 189),
#  ('goals', 188),
#  ('collaborative', 188),
#  ('powerpoint', 188),
#  ('solve', 188),
#  ('contribute', 188),
#  ('machine', 187),
#  ('qualitative', 187),
#  ('report', 186),
#  ('interest', 186),
#  ('passion', 185),
#  ('day', 185),
#  ('deep', 184),
#  ('administration', 184),
#  ('participate', 182),
#  ('core', 182),
#  ('creating', 182),
#  ('includes', 182),
#  ('organizations', 181),
#  ('others', 181),
#  ('academic', 181),
#  ('agency', 181),
#  ('states', 179),
#  ('consideration', 178),
#  ('receive', 177),
#  ('fastpaced', 177),
#  ('physical', 177),
#  ('diversity', 177),
#  ('capital', 177),
#  ('growing', 177),
#  ('datasets', 176),
#  ('fulltime', 176),
#  ('consumer', 175),
#  ('professionals', 174),
#  ('compliance', 174),
#  ('concepts', 173),
#  ('improvement', 173),
#  ('optimization', 172),
#  ('location', 172),
#  ('assistance', 172),
#  ('network', 172),
#  ('requests', 172),
#  ('asset', 172),
#  ('oral', 171),
#  ('evaluation', 171),
#  ('available', 171),
#  ('united', 170),
#  ('commitment', 170),
#  ('actionable', 169),
#  ('creative', 167),
#  ('offer', 167),
#  ('focused', 167),
#  ('essential', 167),
#  ('language', 167),
#  ('ms', 166),
#  ('datadriven', 166),
#  ('enterprise', 166),
#  ('survey', 165),
#  ('together', 165),
#  ('bring', 165),
#  ('present', 165),
#  ('two', 165),
#  ('familiarity', 165),
#  ('international', 165),
#  ('works', 164),
#  ('similar', 164),
#  ('helping', 163),
#  ('applicable', 163),
#  ('approach', 163),
#  ('order', 162),
#  ('serve', 161),
#  ('track', 161),
#  ('potential', 161),
#  ('necessary', 161),
#  ('objectives', 160),
#  ('open', 160),
#  ('commercial', 159),
#  ('proven', 158),
#  ('equity', 158),
#  ('agencies', 157),
#  ('users', 156),
#  ('ideal', 156),
#  ('accounting', 156),
#  ('conducting', 155),
#  ('priorities', 155),
#  ('marital', 154),
#  ('ad', 154),
#  ('content', 154),
#  ('meetings', 154),
#  ('vision', 153),
#  ('integrity', 152),
#  ('execute', 152),
#  ('comprehensive', 152),
#  ('web', 152),
#  ('groups', 151),
#  ('ongoing', 151),
#  ('execution', 151),
#  ('infrastructure', 151),
#  ('salary', 151),
#  ('expert', 151),
#  ('timely', 150),
#  ('deadlines', 149),
#  ('languages', 148),
#  ('leader', 148),
#  ('platforms', 148),
#  ('word', 148),
#  ('processing', 147),
#  ('collaboration', 147),
#  ('leaders', 147),
#  ('desired', 147),
#  ('audiences', 147),
#  ('evaluate', 146),
#  ('economic', 146),
#  ('complete', 145),
#  ('driven', 145),
#  ('scientific', 145),
#  ('responsibility', 145),
#  ('resume', 145),
#  ('predictive', 145),
#  ('different', 144),
#  ('produce', 144),
#  ('dynamic', 144),
#  ('changes', 144),
#  ('estate', 144),
#  ('medicine', 144),
#  ('sciences', 143),
#  ('quickly', 142),
#  ('summary', 142),
#  ('materials', 142),
#  ('energy', 142),
#  ('clear', 141),
#  ('colleagues', 141),
#  ('maintaining', 140),
#  ('functional', 140),
#  ('excellence', 140),
#  ('private', 140),
#  ('record', 139),
#  ('practice', 139),
#  ('prepare', 139),
#  ('define', 138),
#  ('manner', 138),
#  ('documents', 138),
#  ('flexible', 138),
#  ('case', 137),
#  ('passionate', 137),
#  ('delivering', 137),
#  ('full', 137),
#  ('achieve', 137),
#  ('insight', 137),
#  ('major', 136),
#  ('grow', 136),
#  ('three', 136),
#  ('offers', 136),
#  ('personal', 136),
#  ('accredited', 136),
#  ('directly', 135),
#  ('package', 135),
#  ('visit', 135),
#  ('clearance', 135),
#  ('discipline', 135),
#  ('cover', 135),
#  ('san', 135),
#  ('applying', 134),
#  ('approaches', 134),
#  ('right', 133),
#  ('matter', 133),
#  ('cost', 133),
#  ('considered', 132),
#  ('director', 132),
#  ('think', 132),
#  ('expression', 131),
#  ('trading', 131),
#  ('set', 131),
#  ('broad', 131),
#  ('measurement', 131),
#  ('throughout', 131),
#  ('contact', 131),
#  ('offices', 131),
#  ('monitoring', 130),
#  ('guidance', 130),
#  ('dashboards', 130),
#  ('bank', 130),
#  ('hours', 130),
#  ('advertising', 130),
#  ('hiring', 130),
#  ('overview', 130),
#  ('unique', 130),
#  ('10', 129),
#  ('wide', 129),
#  ('veterans', 129),
#  ('bcg', 129),
#  ('person', 128),
#  ('implementing', 128),
#  ('top', 128),
#  ('want', 128),
#  ('applied', 128),
#  ('click', 128),
#  ('experts', 128),
#  ('production', 127),
#  ('power', 127),
#  ('revenue', 127),
#  ('compensation', 127),
#  ('dedicated', 126),
#  ('demonstrate', 126),
#  ('regulatory', 126),
#  ('first', 125),
#  ('environmental', 125),
#  ('great', 125),
#  ('enhance', 125),
#  ('maintenance', 125),
#  ('find', 124),
#  ('comfortable', 124),
#  ('school', 124),
#  ('monitor', 124),
#  ('uw', 124),
#  ('aspects', 123),
#  ('get', 123),
#  ('end', 123),
#  ('accuracy', 122),
#  ('deliverables', 122),
#  ('countries', 122),
#  ('document', 121),
#  ('human', 121),
#  ('direct', 121),
#  ('bi', 121),
#  ('identifying', 121),
#  ('control', 121),
#  ('outcomes', 121),
#  ('regulations', 121),
#  ('genetic', 120),
#  ('reviews', 120),
#  ('see', 120),
#  ('leverage', 120),
#  ('departments', 120),
#  ('letter', 120),
#  ('possess', 119),
#  ('small', 119),
#  ('citizenship', 119),
#  ('supports', 118),
#  ('study', 118),
#  ('engagement', 118),
#  ('inform', 118),
#  ('values', 118),
#  ('regular', 118),
#  ('overall', 118),
#  ('addition', 118),
#  ('address', 118),
#  ('validation', 117),
#  ('place', 117),
#  ('would', 116),
#  ('proprietary', 116),
#  ('audience', 116),
#  ('determine', 116),
#  ('independent', 116),
#  ('type', 115),
#  ('conditions', 115),
#  ('write', 115),
#  ('scale', 115),
#  ('crossfunctional', 115),
#  ('expected', 115),
#  ('accurate', 115),
#  ('act', 115),
#  ('share', 114),
#  ('prioritize', 114),
#  ('specialization', 114),
#  ('mining', 113),
#  ('interpret', 113),
#  ('ways', 113),
#  ('experienced', 113),
#  ('administrative', 113),
#  ('performing', 113),
#  ('banking', 113),
#  ('cancer', 113),
#  ('surveys', 112),
#  ('active', 112),
#  ('prior', 111),
#  ('clearly', 111),
#  ('sector', 111),
#  ('executive', 110),
#  ('c', 110),
#  ('driving', 110),
#  ('designing', 110),
#  ('acquisition', 110),
#  ('events', 109),
#  ('assets', 109),
#  ('direction', 109),
#  ('affirmative', 109),
#  ('extensive', 109),
#  ('boston', 109),
#  ('supply', 108),
#  ('combination', 108),
#  ('exceptional', 108),
#  ('abilities', 107),
#  ('fast', 107),
#  ('paid', 107),
#  ('businesses', 107),
#  ('special', 107),
#  ('generate', 107),
#  ('next', 107),
#  ('submit', 107),
#  ('things', 107),
#  ('family', 106),
#  ('largest', 106),
#  ('criminal', 106),
#  ('influence', 105),
#  ('positions', 105),
#  ('washington', 105),
#  ('drug', 104),
#  ('changing', 104),
#  ('via', 104),
#  ('daily', 104),
#  ('tracking', 104),
#  ('efficient', 104),
#  ('forecasting', 103),
#  ('supervision', 103),
#  ('higher', 103),
#  ('love', 103),
#  ('code', 103),
#  ('thrive', 103),
#  ('institutional', 102),
#  ('dental', 102),
#  ('schedule', 102),
#  ('source', 102),
#  ('interact', 102),
#  ('line', 102),
#  ('initiative', 102),
#  ('enable', 102),
#  ('political', 102),
#  ('locations', 101),
#  ('talent', 101),
#  ('proficient', 100),
#  ('site', 100),
#  ('phd', 100),
#  ('division', 100),
#  ('established', 100),
#  ('date', 100),
#  ('workplace', 100),
#  ('workforce', 99),
#  ('regarding', 99),
#  ('institutions', 99),
#  ('retail', 99),
#  ('assists', 99),
#  ('creation', 98),
#  ('standard', 98),
#  ('per', 98),
#  ('consistent', 98),
#  ('firms', 98),
#  ('nyu', 98),
#  ('completion', 97),
#  ('request', 97),
#  ('require', 97),
#  ('efficiency', 96),
#  ('view', 96),
#  ('coding', 96),
#  ('hospital', 96),
#  ('detailed', 96),
#  ('develops', 96),
#  ('4', 96),
#  ('budget', 96),
#  ('america', 95),
#  ('investments', 95),
#  ('requirement', 95),
#  ('researchers', 95),
#  ('interview', 95),
#  ('francisco', 95),
#  ('scientist', 94),
#  ('important', 94),
#  ('queries', 94),
#  ('applicant', 94),
#  ('proactively', 94),
#  ('optimize', 94),
#  ('military', 94),
#  ('eeo', 93),
#  ('desire', 93),
#  ('effectiveness', 93),
#  ('principles', 93),
#  ('experiences', 93),
#  ('email', 93),
#  ('positive', 93),
#  ('characteristic', 92),
#  ('home', 92),
#  ('account', 92),
#  ('patient', 92),
#  ('pricing', 92),
#  ('setting', 92),
#  ('relationship', 92),
#  ('improvements', 91),
#  ('inc', 91),
#  ('preferably', 91),
#  ('campaigns', 91),
#  ('know', 90),
#  ('meaningful', 90),
#  ('strongly', 90),
#  ('believe', 90),
#  ('maintains', 90),
#  ('thought', 90),
#  ('behavior', 90),
#  ('transportation', 90),
#  ('laws', 90),
#  ('chicago', 90),
#  ('communities', 89),
#  ('solid', 89),
#  ('annual', 89),
#  ('backgrounds', 89),
#  ('legal', 89),
#  ('rapidly', 89),
#  ('ensuring', 88),
#  ('longterm', 88),
#  ('defense', 88),
#  ('interested', 88),
#  ('income', 88),
#  ('algorithms', 88),
#  ('outside', 88),
#  ('many', 88),
#  ('mobile', 88),
#  ('performs', 87),
#  ('investors', 87),
#  ('motivated', 87),
#  ('along', 87),
#  ('2018', 87),
#  ('architecture', 87),
#  ('cloud', 87),
#  ('continuous', 87),
#  ('capacity', 87),
#  ('assess', 86),
#  ('hoc', 86),
#  ('regression', 86),
#  ('tables', 86),
#  ('currently', 86),
#  ('associated', 86),
#  ('contract', 86),
#  ('industries', 86),
#  ('brand', 86),
#  ('eligible', 86),
#  ('student', 86),
#  ('biological', 86),
#  ('significant', 85),
#  ('guide', 85),
#  ('topics', 85),
#  ('engage', 85),
#  ('governance', 85),
#  ('coordinate', 85),
#  ('mathematical', 85),
#  ('disabilities', 85),
#  ('spss', 85),
#  ('unit', 85),
#  ('come', 85),
#  ('ie', 85),
#  ('exciting', 85),
#  ('inventory', 84),
#  ('chain', 84),
#  ('function', 84),
#  ('generation', 84),
#  ('assessment', 84),
#  ('resource', 84),
#  ('due', 83),
#  ('daytoday', 83),
#  ('collaboratively', 83),
#  ('possible', 83),
#  ('companys', 83),
#  ('outstanding', 83),
#  ('integrated', 83),
#  ('recruiting', 83),
#  ('coverage', 82),
#  ('aws', 82),
#  ('demonstrates', 81),
#  ('translate', 81),
#  ('class', 81),
#  ('upon', 81),
#  ('note', 81),
#  ('lives', 80),
#  ('collect', 80),
#  ('compelling', 80),
#  ('campaign', 80),
#  ('history', 80),
#  ('suite', 79),
#  ('401k', 79),
#  ('java', 79),
#  ('among', 79),
#  ('math', 79),
#  ('integration', 79),
#  ('custom', 79),
#  ('willingness', 79),
#  ('player', 79),
#  ('helps', 79),
#  ('progress', 78),
#  ('personnel', 78),
#  ('measure', 78),
#  ('billion', 78),
#  ('details', 78),
#  ('enjoy', 78),
#  ('coordination', 78),
#  ('however', 78),
#  ('feedback', 78),
#  ('decisionmaking', 77),
#  ('records', 77),
#  ('curiosity', 77),
#  ('solution', 77),
#  ('challenging', 77),
#  ('entrepreneurial', 77),
#  ('search', 77),
#  ('stata', 76),
#  ('exposure', 76),
#  ('actively', 76),
#  ('multitask', 76),
#  ('five', 76),
#  ('youre', 76),
#  ('epic', 76),
#  ('reasonable', 76),
#  ('emerging', 76),
#  ('consultants', 76),
#  ('posting', 76),
#  ('prepares', 76),
#  ('long', 76),
#  ('dc', 76),
#  ('located', 75),
#  ('resolve', 75),
#  ('scripting', 75),
#  ('100', 75),
#  ('mental', 75),
#  ('developers', 75),
#  ('certification', 75),
#  ('start', 75),
#  ('fields', 75),
#  ('tax', 75),
#  ('mellon', 75),
#  ('purpose', 74),
#  ('scope', 74),
#  ('previous', 74),
#  ('reach', 74),
#  ('completed', 74),
#  ('sectors', 74),
#  ('balance', 74),
#  ('made', 74),
#  ('monthly', 74),
#  ('onsite', 74),
#  ('indepth', 74),
#  ('automation', 73),
#  ('brands', 73),
#  ('desirable', 73),
#  ('advance', 73),
#  ('faculty', 73),
#  ('consider', 73),
#  ('close', 73),
#  ('handson', 73),
#  ('units', 73),
#  ('nature', 72),
#  ('competencies', 72),
#  ('successfully', 72),
#  ('adhoc', 72),
#  ('statement', 72),
#  ('proud', 72),
#  ('fixed', 72),
#  ('go', 72),
#  ('amazon', 72),
#  ('cycle', 72),
#  ('worldwide', 72),
#  ('35', 72),
#  ('days', 72),
#  ('course', 72),
#  ('residency', 72),
#  ('assurance', 71),
#  ('safety', 71),
#  ('pay', 71),
#  ('shift', 71),
#  ('preparation', 71),
#  ('meeting', 71),
#  ('problemsolving', 71),
#  ('respect', 71),
#  ('updates', 71),
#  ('handle', 71),
#  ('facilitate', 71),
#  ('practical', 71),
#  ('students', 71),
#  ('jll', 71),
#  ('langone', 71),
#  ('ownership', 70),
#  ('check', 70),
#  ('obtain', 70),
#  ('makes', 70),
#  ('matlab', 70),
#  ('valuation', 70),
#  ('oriented', 70),
#  ('ecosystem', 70),
#  ('difference', 70),
#  ('benefit', 70),
#  ('preparing', 70),
#  ('industrial', 70),
#  ('judgment', 70),
#  ('space', 70),
#  ('institute', 70),
#  ('proactive', 69),
#  ('options', 69),
#  ('nontechnical', 69),
#  ('regional', 69),
#  ('manages', 69),
#  ('institution', 69),
#  ('serves', 69),
#  ('environments', 69),
#  ('someone', 69),
#  ('operating', 69),
#  ('6', 69),
#  ('answer', 69),
#  ('presenting', 69),
#  ('curious', 69),
#  ('civil', 69),
#  ('visualizations', 68),
#  ('common', 68),
#  ('structure', 68),
#  ('consumers', 68),
#  ('selection', 68),
#  ...]

# %% [markdown]
# ### Data Scientist

# %%
## merge all the description together in one variable
scient_descrip = ""
for descrip in ds['description']:
    scient_descrip += " " + descrip

## import english stop_words (I, am, in, the...)
from nltk.corpus import stopwords
extra_stopword = ['data','experience','work','team','will','skill','year','skills']
stop_words1 = set((stopwords.words('english')))
stop_words = stop_words1.union(extra_stopword)

## transform the description in a tokenized list of words
from nltk.tokenize import word_tokenize
scient_descrip_low= scient_descrip.lower()
tokens = word_tokenize(str(scient_descrip_low))

## count the frequency of witch tokenized word (without stop_words)
filtered_descrip_scient = []
for word in tokens:
    if word not in list(stop_words):
        filtered_descrip_scient += [word]
        
from collections import Counter
Counter(filtered_descrip_scient).most_common()
# Out:
# [('learning', 7196),
#  ('research', 5956),
#  ('machine', 5734),
#  ('science', 5601),
#  ('development', 5535),
#  ('business', 5245),
#  ('analysis', 4476),
#  ('years', 4194),
#  ('new', 4166),
#  ('ability', 4126),
#  ('strong', 3439),
#  ('including', 3390),
#  ('working', 3303),
#  ('scientist', 3204),
#  ('technical', 3176),
#  ('knowledge', 3124),
#  ('design', 3113),
#  ('analytics', 3064),
#  ('develop', 3020),
#  ('product', 3017),
#  ('models', 2988),
#  ('engineering', 2981),
#  ('solutions', 2835),
#  ('related', 2796),
#  ('support', 2770),
#  ('teams', 2754),
#  ('company', 2701),
#  ('software', 2668),
#  ('environment', 2637),
#  ('required', 2590),
#  ('using', 2557),
#  ('statistical', 2551),
#  ('techniques', 2516),
#  ('opportunity', 2505),
#  ('qualifications', 2489),
#  ('status', 2400),
#  ('degree', 2374),
#  ('computer', 2371),
#  ('projects', 2361),
#  ('management', 2344),
#  ('systems', 2328),
#  ('information', 2294),
#  ('products', 2294),
#  ('technology', 2273),
#  ('help', 2223),
#  ('field', 2185),
#  ('us', 2175),
#  ('responsibilities', 2164),
#  ('python', 2155),
#  ('tools', 2149),
#  ('problems', 2139),
#  ('scientific', 2121),
#  ('communication', 2088),
#  ('position', 2087),
#  ('requirements', 2082),
#  ('project', 2068),
#  ('andor', 2064),
#  ('algorithms', 2063),
#  ('clinical', 2062),
#  ('build', 2038),
#  ('understanding', 2006),
#  ('analytical', 1995),
#  ('preferred', 1992),
#  ('job', 1962),
#  ('phd', 1919),
#  ('role', 1908),
#  ('modeling', 1900),
#  ('advanced', 1887),
#  ('statistics', 1886),
#  ('one', 1872),
#  ('amp', 1872),
#  ('across', 1869),
#  ('methods', 1856),
#  ('provide', 1842),
#  ('industry', 1806),
#  ('scientists', 1801),
#  ('employment', 1793),
#  ('people', 1764),
#  ('technologies', 1752),
#  ('results', 1726),
#  ('deep', 1719),
#  ('customers', 1717),
#  ('large', 1707),
#  ('complex', 1704),
#  ('use', 1699),
#  ('etc', 1696),
#  ('equal', 1673),
#  ('well', 1653),
#  ('developing', 1641),
#  ('building', 1619),
#  ('expertise', 1611),
#  ('within', 1606),
#  ('eg', 1564),
#  ('health', 1553),
#  ('processing', 1551),
#  ('services', 1551),
#  ('make', 1535),
#  ('looking', 1530),
#  ('insights', 1527),
#  ('language', 1521),
#  ('must', 1512),
#  ('process', 1512),
#  ('candidate', 1509),
#  ('customer', 1506),
#  ('disability', 1503),
#  ('biology', 1465),
#  ('gender', 1450),
#  ('highly', 1413),
#  ('excellent', 1408),
#  ('relevant', 1400),
#  ('key', 1398),
#  ('world', 1397),
#  ('time', 1387),
#  ('r', 1386),
#  ('lead', 1372),
#  ('employer', 1372),
#  ('programming', 1356),
#  ('impact', 1352),
#  ('join', 1349),
#  ('quality', 1341),
#  ('quantitative', 1319),
#  ('apply', 1311),
#  ('drive', 1304),
#  ('global', 1297),
#  ('best', 1290),
#  ('applications', 1286),
#  ('national', 1264),
#  ('responsible', 1260),
#  ('may', 1247),
#  ('plus', 1246),
#  ('also', 1239),
#  ('part', 1236),
#  ('high', 1230),
#  ('big', 1226),
#  ('written', 1201),
#  ('medical', 1191),
#  ('drug', 1187),
#  ('engineers', 1186),
#  ('operations', 1185),
#  ('platform', 1170),
#  ('orientation', 1166),
#  ('group', 1163),
#  ('veteran', 1158),
#  ('innovative', 1156),
#  ('clients', 1156),
#  ('applicants', 1149),
#  ('opportunities', 1142),
#  ('performance', 1140),
#  ('leading', 1126),
#  ('include', 1122),
#  ('sexual', 1117),
#  ('based', 1102),
#  ('internal', 1100),
#  ('employees', 1094),
#  ('multiple', 1089),
#  ('cell', 1087),
#  ('improve', 1087),
#  ('identify', 1083),
#  ('able', 1080),
#  ('areas', 1075),
#  ('please', 1069),
#  ('create', 1066),
#  ('sql', 1062),
#  ('color', 1062),
#  ('race', 1051),
#  ('demonstrated', 1047),
#  ('perform', 1045),
#  ('application', 1037),
#  ('discovery', 1026),
#  ('senior', 1021),
#  ('youll', 1021),
#  ('marketing', 1020),
#  ('organization', 1018),
#  ('applied', 1016),
#  ('external', 1015),
#  ('origin', 1015),
#  ('religion', 1014),
#  ('sets', 998),
#  ('optimization', 996),
#  ('reports', 994),
#  ('minimum', 991),
#  ('identity', 990),
#  ('diverse', 982),
#  ('benefits', 974),
#  ('scale', 973),
#  ('understand', 971),
#  ('predictive', 968),
#  ('processes', 957),
#  ('least', 951),
#  ('collaborate', 949),
#  ('various', 947),
#  ('analyze', 944),
#  ('background', 934),
#  ('deliver', 934),
#  ('qualified', 930),
#  ('google', 930),
#  ('needs', 926),
#  ('age', 922),
#  ('vision', 919),
#  ('communicate', 918),
#  ('testing', 914),
#  ('record', 911),
#  ('decisions', 902),
#  ('value', 901),
#  ('mathematics', 900),
#  ('successful', 898),
#  ('programs', 898),
#  ('5', 894),
#  ('training', 892),
#  ('laboratory', 892),
#  ('leadership', 891),
#  ('following', 888),
#  ('protected', 884),
#  ('life', 883),
#  ('cloud', 881),
#  ('level', 879),
#  ('natural', 876),
#  ('without', 872),
#  ('intelligence', 870),
#  ('culture', 867),
#  ('implement', 865),
#  ('candidates', 864),
#  ('education', 863),
#  ('masters', 858),
#  ('experiments', 852),
#  ('model', 851),
#  ('ai', 850),
#  ('innovation', 849),
#  ('solve', 846),
#  ('2', 844),
#  ('partners', 844),
#  ('need', 838),
#  ('mission', 833),
#  ('like', 833),
#  ('mining', 832),
#  ('closely', 830),
#  ('production', 829),
#  ('seeking', 826),
#  ('client', 823),
#  ('novel', 818),
#  ('studies', 814),
#  ('learn', 813),
#  ('languages', 810),
#  ('system', 798),
#  ('variety', 788),
#  ('effectively', 786),
#  ('professional', 782),
#  ('activities', 771),
#  ('solving', 770),
#  ('3', 762),
#  ('ms', 762),
#  ('problem', 759),
#  ('independently', 758),
#  ('collaborative', 757),
#  ('growth', 754),
#  ('ensure', 751),
#  ('stakeholders', 749),
#  ('molecular', 745),
#  ('java', 744),
#  ('contribute', 742),
#  ('program', 740),
#  ('individual', 739),
#  ('manage', 732),
#  ('description', 730),
#  ('committed', 730),
#  ('human', 729),
#  ('analyses', 728),
#  ('around', 728),
#  ('ml', 727),
#  ('approaches', 727),
#  ('track', 726),
#  ('equivalent', 724),
#  ('members', 723),
#  ('action', 722),
#  ('practices', 717),
#  ('spark', 712),
#  ('focus', 712),
#  ('computational', 709),
#  ('regulatory', 705),
#  ('sex', 696),
#  ('sources', 695),
#  ('platforms', 690),
#  ('assays', 690),
#  ('digital', 685),
#  ('future', 683),
#  ('c', 680),
#  ('service', 680),
#  ('amazon', 676),
#  ('individuals', 672),
#  ('state', 669),
#  ('basic', 668),
#  ('good', 667),
#  ('verbal', 667),
#  ('familiarity', 659),
#  ('chemistry', 653),
#  ('small', 651),
#  ('strategy', 650),
#  ('appropriate', 646),
#  ('regard', 645),
#  ('growing', 644),
#  ('every', 643),
#  ('collaboration', 640),
#  ('handson', 640),
#  ('success', 639),
#  ('financial', 638),
#  ('core', 637),
#  ('hadoop', 636),
#  ('experimental', 636),
#  ('ideas', 633),
#  ('proficiency', 631),
#  ('decision', 631),
#  ('expert', 631),
#  ('sciences', 630),
#  ('code', 625),
#  ('better', 624),
#  ('genetic', 624),
#  ('challenges', 624),
#  ('present', 623),
#  ('office', 619),
#  ('proven', 618),
#  ('study', 617),
#  ('strategic', 614),
#  ('area', 612),
#  ('applying', 611),
#  ('datasets', 608),
#  ('way', 607),
#  ('marital', 605),
#  ('computing', 603),
#  ('functional', 603),
#  ('goals', 603),
#  ('staff', 602),
#  ('visualization', 601),
#  ('travel', 601),
#  ('others', 600),
#  ('implementation', 600),
#  ('review', 597),
#  ('safety', 597),
#  ('companies', 595),
#  ('healthcare', 593),
#  ('discipline', 592),
#  ('making', 592),
#  ('critical', 592),
#  ('san', 590),
#  ('great', 589),
#  ('duties', 588),
#  ('public', 588),
#  ('test', 588),
#  ('maintain', 587),
#  ('user', 586),
#  ('passion', 586),
#  ('recommendations', 585),
#  ('providing', 584),
#  ('capabilities', 584),
#  ('efforts', 582),
#  ('cancer', 581),
#  ('risk', 580),
#  ('competitive', 579),
#  ('delivery', 576),
#  ('unique', 575),
#  ('creative', 573),
#  ('plans', 572),
#  ('1', 569),
#  ('focused', 568),
#  ('strategies', 566),
#  ('expression', 565),
#  ('conduct', 562),
#  ('range', 559),
#  ('creating', 559),
#  ('plan', 558),
#  ('applicable', 557),
#  ('bring', 554),
#  ('crossfunctional', 553),
#  ('take', 552),
#  ('bachelors', 551),
#  ('care', 551),
#  ('lab', 549),
#  ('community', 549),
#  ('content', 548),
#  ('physical', 547),
#  ('partner', 545),
#  ('distributed', 544),
#  ('users', 543),
#  ('infrastructure', 539),
#  ('writing', 538),
#  ('federal', 537),
#  ('passionate', 536),
#  ('similar', 535),
#  ('fastpaced', 534),
#  ('current', 533),
#  ('effective', 532),
#  ('manufacturing', 531),
#  ('concepts', 531),
#  ('day', 531),
#  ('analyzing', 531),
#  ('participate', 530),
#  ('provides', 530),
#  ('execute', 528),
#  ('different', 528),
#  ('dynamic', 526),
#  ('member', 523),
#  ('documents', 523),
#  ('next', 523),
#  ('real', 519),
#  ('analytic', 519),
#  ('security', 517),
#  ('insurance', 515),
#  ('functions', 513),
#  ('presentations', 513),
#  ('planning', 512),
#  ('department', 509),
#  ('leader', 508),
#  ('questions', 508),
#  ('generation', 508),
#  ('sales', 505),
#  ('requires', 505),
#  ('essential', 504),
#  ('specific', 504),
#  ('meet', 503),
#  ('execution', 502),
#  ('delivering', 502),
#  ('local', 499),
#  ('patients', 498),
#  ('access', 497),
#  ('center', 497),
#  ('enable', 496),
#  ('databases', 493),
#  ('bioinformatics', 490),
#  ('additional', 488),
#  ('existing', 484),
#  ('assist', 480),
#  ('career', 479),
#  ('used', 477),
#  ('evaluate', 475),
#  ('issues', 474),
#  ('fields', 472),
#  ('disease', 472),
#  ('basis', 471),
#  ('primary', 471),
#  ('needed', 470),
#  ('findings', 470),
#  ('together', 470),
#  ('artificial', 467),
#  ('motivated', 467),
#  ('networks', 466),
#  ('grow', 465),
#  ('academic', 465),
#  ('potential', 464),
#  ('validation', 463),
#  ('managing', 463),
#  ('market', 463),
#  ('open', 462),
#  ('leverage', 459),
#  ('search', 459),
#  ('meetings', 458),
#  ('want', 457),
#  ('scalable', 455),
#  ('law', 455),
#  ('aws', 455),
#  ('online', 453),
#  ('kpmg', 452),
#  ('ideal', 452),
#  ('employee', 451),
#  ('offer', 451),
#  ('millions', 450),
#  ('reporting', 449),
#  ('engineer', 449),
#  ('wide', 449),
#  ('states', 449),
#  ('worlds', 449),
#  ('actionable', 448),
#  ('location', 448),
#  ('physics', 447),
#  ('methodologies', 447),
#  ('york', 446),
#  ('limited', 445),
#  ('media', 445),
#  ('oral', 444),
#  ('protein', 444),
#  ('change', 443),
#  ('driven', 441),
#  ('find', 441),
#  ('tasks', 437),
#  ('resources', 437),
#  ('network', 436),
#  ('control', 436),
#  ('consulting', 435),
#  ('directly', 434),
#  ('solid', 434),
#  ('talented', 434),
#  ('therapeutics', 434),
#  ('interpersonal', 431),
#  ('social', 430),
#  ('presentation', 430),
#  ('broad', 428),
#  ('consumer', 428),
#  ('set', 428),
#  ('top', 428),
#  ('initiatives', 427),
#  ('diseases', 427),
#  ('experienced', 426),
#  ('procedures', 426),
#  ('diversity', 426),
#  ('experiences', 426),
#  ('get', 423),
#  ('nlp', 422),
#  ('francisco', 422),
#  ('biological', 421),
#  ('datadriven', 421),
#  ('designing', 420),
#  ('database', 418),
#  ('significant', 415),
#  ('extensive', 414),
#  ('documentation', 413),
#  ('characterization', 413),
#  ('commercial', 412),
#  ('define', 412),
#  ('sas', 412),
#  ('serve', 411),
#  ('order', 410),
#  ('10', 409),
#  ('regression', 409),
#  ('lives', 408),
#  ('publications', 407),
#  ('operational', 407),
#  ('desired', 407),
#  ('currently', 406),
#  ('optimize', 404),
#  ('advance', 403),
#  ('achieve', 403),
#  ('neural', 403),
#  ('relationships', 403),
#  ('microsoft', 403),
#  ('4', 402),
#  ('protocols', 402),
#  ('includes', 400),
#  ('web', 400),
#  ('power', 399),
#  ('trends', 397),
#  ('available', 397),
#  ('subject', 396),
#  ('expected', 395),
#  ('recognition', 395),
#  ('excellence', 392),
#  ('largescale', 392),
#  ('helping', 391),
#  ('organizational', 391),
#  ('full', 391),
#  ('metrics', 390),
#  ('driving', 389),
#  ('direct', 388),
#  ('fast', 387),
#  ('interest', 386),
#  ('love', 386),
#  ('approach', 384),
#  ('ways', 383),
#  ('generate', 382),
#  ('know', 382),
#  ('policy', 381),
#  ('type', 379),
#  ('classification', 379),
#  ('startup', 378),
#  ('scripting', 377),
#  ('right', 377),
#  ('frameworks', 376),
#  ('source', 374),
#  ('economics', 373),
#  ('architecture', 372),
#  ('evaluation', 372),
#  ('come', 372),
#  ('personal', 371),
#  ('manner', 371),
#  ('organizations', 370),
#  ('implementing', 370),
#  ('comfortable', 370),
#  ('groups', 368),
#  ('managers', 368),
#  ('consideration', 368),
#  ('edge', 367),
#  ('assay', 367),
#  ('features', 366),
#  ('ancestry', 366),
#  ('united', 366),
#  ('resumes', 366),
#  ('enterprise', 366),
#  ('vivo', 366),
#  ('package', 365),
#  ('supporting', 364),
#  ('practical', 364),
#  ('exciting', 363),
#  ('agencies', 362),
#  ('pharmaceutical', 362),
#  ('accommodation', 362),
#  ('speech', 359),
#  ('collection', 358),
#  ('receive', 358),
#  ('inc', 358),
#  ('tensorflow', 357),
#  ('discover', 356),
#  ('offers', 356),
#  ('comprehensive', 355),
#  ('performing', 355),
#  ('would', 355),
#  ('leveraging', 354),
#  ('environmental', 353),
#  ('advertising', 352),
#  ('rampd', 351),
#  ('works', 351),
#  ('mathematical', 351),
#  ('scala', 351),
#  ('outcomes', 348),
#  ('summary', 348),
#  ('thinking', 348),
#  ('immunology', 348),
#  ('solution', 347),
#  ('rapidly', 347),
#  ('standards', 346),
#  ('objectives', 345),
#  ('pipelines', 344),
#  ('largest', 344),
#  ('consider', 343),
#  ('standard', 342),
#  ('general', 341),
#  ('prior', 340),
#  ('clear', 338),
#  ('detection', 338),
#  ('environments', 337),
#  ('portfolio', 337),
#  ('detail', 336),
#  ('address', 336),
#  ('matlab', 333),
#  ('leaders', 333),
#  ('therapeutic', 333),
#  ('guidance', 332),
#  ('tech', 332),
#  ('hive', 332),
#  ('setting', 331),
#  ('citizenship', 331),
#  ('major', 331),
#  ('firm', 329),
#  ('challenging', 329),
#  ('mobile', 329),
#  ('family', 328),
#  ('levels', 328),
#  ('experts', 328),
#  ('materials', 327),
#  ('conferences', 327),
#  ('government', 327),
#  ('place', 326),
#  ('attention', 326),
#  ('paid', 326),
#  ('explore', 325),
#  ('ca', 325),
#  ('bs', 324),
#  ('businesses', 324),
#  ('researchers', 323),
#  ('audiences', 323),
#  ('considered', 323),
#  ('quickly', 323),
#  ('dedicated', 323),
#  ('assigned', 322),
#  ('investment', 321),
#  ('workplace', 320),
#  ('write', 320),
#  ('fulltime', 320),
#  ('necessary', 317),
#  ('equipment', 317),
#  ('meaningful', 317),
#  ('unstructured', 316),
#  ('multidisciplinary', 315),
#  ('act', 315),
#  ('efficient', 314),
#  ('many', 313),
#  ('colleagues', 313),
#  ('space', 313),
#  ('international', 312),
#  ('youre', 310),
#  ('gene', 310),
#  ('preparation', 308),
#  ('require', 308),
#  ('visit', 307),
#  ('matter', 306),
#  ('compensation', 306),
#  ('first', 306),
#  ('patient', 306),
#  ('target', 305),
#  ('behavior', 305),
#  ('industrial', 304),
#  ('proud', 304),
#  ('assistance', 304),
#  ('changing', 303),
#  ('integration', 302),
#  ('important', 302),
#  ('sequencing', 301),
#  ('conditions', 301),
#  ('cutting', 300),
#  ('exceptional', 300),
#  ('salary', 299),
#  ('flexible', 299),
#  ('pipeline', 299),
#  ('biochemistry', 299),
#  ('junior', 298),
#  ('professionals', 298),
#  ('finance', 298),
#  ('share', 298),
#  ('image', 297),
#  ('structured', 297),
#  ('influence', 297),
#  ('agency', 297),
#  ('interpret', 296),
#  ('math', 296),
#  ('prepare', 296),
#  ('hiring', 296),
#  ('end', 296),
#  ('report', 296),
#  ('thrive', 295),
#  ('consistent', 293),
#  ('regardless', 293),
#  ('developers', 293),
#  ('things', 292),
#  ('transfer', 292),
#  ('401k', 291),
#  ('early', 291),
#  ('packages', 290),
#  ('translate', 290),
#  ('demonstrate', 289),
#  ('believe', 289),
#  ('independent', 287),
#  ('companys', 287),
#  ('supply', 285),
#  ('principles', 285),
#  ('develops', 285),
#  ('university', 284),
#  ('responsibility', 284),
#  ('abilities', 284),
#  ('realworld', 284),
#  ('genetics', 284),
#  ('principal', 283),
#  ('site', 283),
#  ('hands', 283),
#  ('complete', 282),
#  ('two', 282),
#  ('preclinical', 281),
#  ('chemical', 280),
#  ('addition', 279),
#  ('conducting', 278),
#  ('automation', 278),
#  ('creativity', 278),
#  ('function', 278),
#  ('manager', 277),
#  ('practice', 277),
#  ('think', 277),
#  ('nontechnical', 276),
#  ('throughout', 276),
#  ('brands', 276),
#  ('goal', 276),
#  ('improvement', 275),
#  ('via', 275),
#  ('usa', 275),
#  ('algorithm', 274),
#  ('proficient', 274),
#  ('dental', 274),
#  ('transform', 274),
#  ('chain', 273),
#  ('realtime', 273),
#  ('interact', 272),
#  ('laws', 272),
#  ('identifying', 272),
#  ('oncology', 272),
#  ('forward', 271),
#  ('medicine', 269),
#  ('translational', 269),
#  ('genomics', 269),
#  ('analysts', 269),
#  ('worldclass', 269),
#  ('excel', 267),
#  ('cells', 267),
#  ('robust', 266),
#  ('mentor', 265),
#  ('interpretation', 265),
#  ('stateoftheart', 265),
#  ('therapies', 265),
#  ('criminal', 264),
#  ('reasonable', 264),
#  ('targets', 264),
#  ('cellular', 263),
#  ('cuttingedge', 261),
#  ('ongoing', 261),
#  ('enhance', 260),
#  ('direction', 259),
#  ('electrical', 259),
#  ('imaging', 258),
#  ('values', 257),
#  ('forecasting', 257),
#  ('domain', 257),
#  ('discriminate', 257),
#  ('automated', 256),
#  ('compliance', 256),
#  ('contact', 255),
#  ('maintaining', 255),
#  ('pharmacology', 255),
#  ('form', 254),
#  ('live', 253),
#  ('desire', 253),
#  ('benefit', 253),
#  ('agile', 252),
#  ('determine', 252),
#  ('selection', 252),
#  ('feature', 252),
#  ('see', 252),
#  ('boston', 252),
#  ('home', 251),
#  ('coding', 249),
#  ('series', 249),
#  ('modern', 249),
#  ('affirmative', 249),
#  ('document', 249),
#  ('corporate', 249),
#  ('markets', 248),
#  ('mental', 248),
#  ('director', 248),
#  ('contributions', 248),
#  ('located', 247),
#  ('desirable', 247),
#  ('cognitive', 247),
#  ('tableau', 247),
#  ('class', 247),
#  ('possible', 246),
#  ('disciplines', 245),
#  ('flow', 245),
#  ('communicating', 245),
#  ('monitoring', 244),
#  ('text', 244),
#  ('interested', 244),
#  ('clustering', 244),
#  ('hardware', 244),
#  ('person', 243),
#  ('preferably', 242),
#  ('improving', 242),
#  ('guide', 242),
#  ('offices', 242),
#  ('common', 242),
#  ('associate', 241),
#  ('vitro', 241),
#  ('helps', 240),
#  ('talent', 240),
#  ('operating', 239),
#  ('number', 239),
#  ('aspects', 239),
#  ('6', 238),
#  ('literature', 238),
#  ('communications', 238),
#  ('biomarker', 237),
#  ('deploy', 237),
#  ('publication', 236),
#  ('recommendation', 236),
#  ('structures', 236),
#  ('hours', 235),
#  ('problemsolving', 235),
#  ('thought', 234),
#  ('view', 234),
#  ('devices', 233),
#  ('integrate', 233),
#  ('timely', 232),
#  ('records', 232),
#  ('regulations', 232),
#  ('difference', 232),
#  ('empower', 231),
#  ('clearly', 231),
#  ('history', 231),
#  ('accept', 230),
#  ('successfully', 229),
#  ('previous', 229),
#  ('capital', 228),
#  ('million', 227),
#  ('pregnancy', 226),
#  ('fun', 226),
#  ('outstanding', 225),
#  ('supervision', 225),
#  ('communities', 225),
#  ('deployment', 225),
#  ('daily', 225),
#  ('retail', 225),
#  ('hire', 225),
#  ('leads', 224),
#  ('assessment', 224),
#  ('tests', 223),
#  ('retrieval', 223),
#  ('therapy', 223),
#  ('three', 222),
#  ('designs', 222),
#  ('libraries', 221),
#  ('priorities', 221),
#  ('recruiting', 220),
#  ('energy', 220),
#  ('made', 220),
#  ('relational', 220),
#  ('built', 220),
#  ('integrity', 219),
#  ('cross', 219),
#  ('postdoctoral', 219),
#  ('legally', 218),
#  ('patterns', 217),
#  ('email', 217),
#  ('enjoy', 217),
#  ('locations', 217),
#  ('emerging', 217),
#  ('utilize', 216),
#  ('produce', 215),
#  ('associated', 215),
#  ('method', 214),
#  ('credit', 214),
#  ('ad', 214),
#  ('video', 214),
#  ('deliverables', 213),
#  ('establish', 213),
#  ('signal', 213),
#  ('positive', 213),
#  ('100', 213),
#  ('opportunityaffirmative', 213),
#  ('regular', 212),
#  ('8', 211),
#  ('prototype', 211),
#  ('reach', 211),
#  ('feedback', 211),
#  ('capable', 211),
#  ('connect', 210),
#  ('presenting', 210),
#  ('insight', 210),
#  ('ecommerce', 210),
#  ('legal', 210),
#  ('military', 209),
#  ('collaboratively', 209),
#  ('recognized', 209),
#  ('resume', 208),
#  ('outside', 208),
#  ('linux', 208),
#  ('recruitment', 208),
#  ('disabilities', 207),
#  ('especially', 207),
#  ('line', 207),
#  ('personalized', 207),
#  ('continuous', 207),
#  ('someone', 207),
#  ('worldwide', 207),
#  ('utilizing', 206),
#  ('histories', 206),
#  ('special', 206),
#  ('maintenance', 206),
#  ('acquisition', 206),
#  ('cambridge', 205),
#  ('extraction', 204),
#  ('possess', 204),
#  ('efficiency', 204),
#  ('engage', 203),
#  ('overview', 203),
#  ('shape', 203),
#  ('validate', 203),
#  ('engagement', 203),
#  ('latest', 202),
#  ('animal', 202),
#  ('creed', 201),
#  ('simulation', 201),
#  ('identification', 201),
#  ('scope', 201),
#  ('eligibility', 201),
#  ('prioritize', 201),
#  ('along', 201),
#  ('entrepreneurial', 200),
#  ('revenue', 200),
#  ('several', 199),
#  ('play', 199),
#  ('improvements', 199),
#  ('city', 199),
#  ('oriented', 199),
#  ('founded', 199),
#  ('developed', 199),
#  ('audience', 198),
#  ('chance', 198),
#  ('base', 198),
#  ('measurement', 198),
#  ('handling', 197),
#  ('active', 197),
#  ('events', 197),
#  ('authorization', 196),
#  ('ngs', 196),
#  ('beyond', 195),
#  ('commitment', 195),
#  ('operate', 195),
#  ('challenge', 195),
#  ('cc', 195),
#  ('combination', 195),
#  ('contract', 195),
#  ('supports', 194),
#  ('assets', 194),
#  ('date', 194),
#  ('become', 194),
#  ('bonus', 194),
#  ('genomic', 194),
#  ('selfmotivated', 193),
#  ('verification', 192),
#  ...]

# %% [markdown]
# ### Data Engineer

# %%
## merge all the description together in one variable
engine_descrip = ""
for descrip in de['description']:
    engine_descrip += " " + descrip

## import english stop_words (I, am, in, the...)
from nltk.corpus import stopwords
extra_stopword = ['data','experience','work','team','will','skill','year','skills']
stop_words1 = set((stopwords.words('english')))
stop_words = stop_words1.union(extra_stopword)

## transform the description in a tokenized list of words
from nltk.tokenize import word_tokenize
engine_descrip_low= engine_descrip.lower()
tokens = word_tokenize(str(engine_descrip_low))

## count the frequency of witch tokenized word (without stop_words)
filtered_descrip_engine = []
for word in tokens:
    if word not in list(stop_words):
        filtered_descrip_engine += [word]
        
from collections import Counter
Counter(filtered_descrip_engine).most_common()
# Out:
# [('software', 2639),
#  ('design', 2352),
#  ('systems', 2336),
#  ('development', 2315),
#  ('engineering', 2229),
#  ('technical', 1893),
#  ('required', 1609),
#  ('working', 1515),
#  ('years', 1461),
#  ('business', 1455),
#  ('engineers', 1418),
#  ('new', 1364),
#  ('ability', 1313),
#  ('science', 1287),
#  ('support', 1273),
#  ('us', 1263),
#  ('product', 1257),
#  ('including', 1246),
#  ('environment', 1218),
#  ('degree', 1209),
#  ('technologies', 1193),
#  ('scientists', 1133),
#  ('solutions', 1129),
#  ('system', 1126),
#  ('related', 1118),
#  ('products', 1115),
#  ('requirements', 1109),
#  ('engineer', 1069),
#  ('strong', 1063),
#  ('learning', 1051),
#  ('management', 1042),
#  ('knowledge', 1022),
#  ('teams', 999),
#  ('may', 976),
#  ('tools', 974),
#  ('computer', 959),
#  ('technology', 953),
#  ('qualifications', 950),
#  ('test', 949),
#  ('build', 930),
#  ('customers', 910),
#  ('develop', 902),
#  ('research', 897),
#  ('opportunity', 875),
#  ('analysis', 875),
#  ('building', 873),
#  ('help', 862),
#  ('position', 848),
#  ('must', 844),
#  ('company', 835),
#  ('maintain', 812),
#  ('services', 809),
#  ('information', 801),
#  ('machine', 772),
#  ('using', 745),
#  ('security', 734),
#  ('understanding', 733),
#  ('people', 718),
#  ('customer', 713),
#  ('communication', 690),
#  ('complex', 687),
#  ('across', 685),
#  ('amp', 674),
#  ('use', 674),
#  ('developing', 670),
#  ('performance', 665),
#  ('field', 663),
#  ('status', 659),
#  ('provide', 652),
#  ('youll', 652),
#  ('applications', 647),
#  ('andor', 642),
#  ('job', 642),
#  ('preferred', 633),
#  ('one', 633),
#  ('equal', 629),
#  ('best', 626),
#  ('role', 607),
#  ('projects', 604),
#  ('cloud', 604),
#  ('problems', 602),
#  ('quality', 600),
#  ('big', 597),
#  ('responsibilities', 592),
#  ('well', 591),
#  ('python', 586),
#  ('within', 584),
#  ('process', 582),
#  ('platform', 575),
#  ('education', 572),
#  ('large', 566),
#  ('lead', 563),
#  ('testing', 562),
#  ('production', 557),
#  ('aerospace', 557),
#  ('make', 549),
#  ('mission', 544),
#  ('employer', 540),
#  ('high', 531),
#  ('project', 525),
#  ('code', 519),
#  ('plus', 508),
#  ('analytics', 501),
#  ('looking', 500),
#  ('national', 494),
#  ('control', 494),
#  ('disability', 492),
#  ('clearance', 492),
#  ('programming', 490),
#  ('advanced', 481),
#  ('processing', 480),
#  ('perform', 474),
#  ('level', 473),
#  ('architecture', 464),
#  ('need', 462),
#  ('world', 459),
#  ('vision', 457),
#  ('spacecraft', 456),
#  ('processes', 454),
#  ('application', 453),
#  ('etc', 451),
#  ('create', 449),
#  ('industry', 449),
#  ('web', 449),
#  ('excellent', 447),
#  ('time', 446),
#  ('gender', 437),
#  ('infrastructure', 432),
#  ('responsible', 429),
#  ('program', 428),
#  ('also', 428),
#  ('drive', 424),
#  ('highly', 420),
#  ('employment', 420),
#  ('successful', 415),
#  ('scale', 415),
#  ('practices', 413),
#  ('able', 405),
#  ('written', 404),
#  ('part', 402),
#  ('distributed', 401),
#  ('ensure', 401),
#  ('service', 398),
#  ('designing', 398),
#  ('include', 397),
#  ('ball', 396),
#  ('variety', 394),
#  ('learn', 392),
#  ('equipment', 391),
#  ('algorithms', 391),
#  ('java', 390),
#  ('like', 390),
#  ('take', 389),
#  ('innovative', 388),
#  ('join', 387),
#  ('office', 385),
#  ('c', 385),
#  ('key', 384),
#  ('others', 384),
#  ('integration', 381),
#  ('needs', 381),
#  ('implement', 380),
#  ('intelligence', 380),
#  ('multiple', 377),
#  ('travel', 377),
#  ('orientation', 377),
#  ('diverse', 377),
#  ('leadership', 374),
#  ('amazon', 373),
#  ('candidate', 372),
#  ('sexual', 366),
#  ('leading', 363),
#  ('department', 357),
#  ('manufacturing', 357),
#  ('space', 356),
#  ('medical', 353),
#  ('identity', 352),
#  ('programs', 351),
#  ('strategic', 349),
#  ('impact', 349),
#  ('language', 347),
#  ('operations', 346),
#  ('based', 343),
#  ('color', 343),
#  ('collaborate', 342),
#  ('meet', 341),
#  ('veteran', 341),
#  ('senior', 339),
#  ('success', 336),
#  ('bachelors', 335),
#  ('deliver', 335),
#  ('aws', 332),
#  ('minimum', 329),
#  ('group', 329),
#  ('agile', 327),
#  ('models', 327),
#  ('understand', 326),
#  ('expertise', 325),
#  ('various', 325),
#  ('better', 324),
#  ('citizenship', 324),
#  ('access', 323),
#  ('deep', 323),
#  ('clients', 322),
#  ('hardware', 322),
#  ('challenges', 319),
#  ('duties', 316),
#  ('sql', 314),
#  ('opportunities', 314),
#  ('manage', 314),
#  ('organization', 313),
#  ('features', 312),
#  ('issues', 310),
#  ('benefits', 309),
#  ('race', 308),
#  ('every', 306),
#  ('demonstrated', 306),
#  ('please', 305),
#  ('improve', 305),
#  ('staff', 304),
#  ('applicants', 303),
#  ('bring', 301),
#  ('equivalent', 301),
#  ('effective', 301),
#  ('closely', 300),
#  ('way', 300),
#  ('masters', 299),
#  ('around', 299),
#  ('origin', 299),
#  ('effectively', 299),
#  ('microsoft', 298),
#  ('religion', 295),
#  ('employees', 295),
#  ('5', 295),
#  ('apply', 294),
#  ('phd', 294),
#  ('3', 288),
#  ('google', 288),
#  ('electrical', 287),
#  ('employee', 285),
#  ('eg', 284),
#  ('languages', 282),
#  ('age', 282),
#  ('ai', 282),
#  ('delivery', 281),
#  ('implementation', 281),
#  ('professional', 280),
#  ('scalable', 280),
#  ('internal', 279),
#  ('user', 278),
#  ('solving', 277),
#  ('managers', 271),
#  ('2', 269),
#  ('future', 268),
#  ('protected', 268),
#  ('available', 267),
#  ('get', 267),
#  ('bs', 267),
#  ('conditions', 267),
#  ('spark', 266),
#  ('concepts', 266),
#  ('remote', 265),
#  ('without', 264),
#  ('relocation', 264),
#  ('problem', 262),
#  ('network', 261),
#  ('helping', 261),
#  ('pipelines', 261),
#  ('qualified', 261),
#  ('core', 261),
#  ('passion', 261),
#  ('relevant', 261),
#  ('enable', 260),
#  ('techniques', 259),
#  ('source', 259),
#  ('automation', 257),
#  ('relationships', 257),
#  ('analytical', 256),
#  ('plans', 256),
#  ('users', 256),
#  ('necessary', 256),
#  ('market', 255),
#  ('interact', 254),
#  ('description', 253),
#  ('activities', 253),
#  ('value', 253),
#  ('current', 251),
#  ('good', 251),
#  ('achieve', 251),
#  ('culture', 250),
#  ('schedule', 248),
#  ('together', 247),
#  ('standards', 247),
#  ('members', 246),
#  ('want', 245),
#  ('platforms', 245),
#  ('global', 245),
#  ('verbal', 243),
#  ('power', 243),
#  ('exciting', 243),
#  ('analyze', 242),
#  ('proven', 241),
#  ('background', 241),
#  ('decisions', 240),
#  ('database', 240),
#  ('basic', 240),
#  ('marketing', 239),
#  ('documentation', 239),
#  ('digital', 239),
#  ('worlds', 237),
#  ('health', 237),
#  ('critical', 236),
#  ('day', 235),
#  ('planning', 235),
#  ('identify', 234),
#  ('experiences', 234),
#  ('results', 233),
#  ('functional', 233),
#  ('ms', 233),
#  ('databases', 233),
#  ('following', 233),
#  ('providing', 231),
#  ('procedures', 231),
#  ('creating', 230),
#  ('great', 230),
#  ('sex', 229),
#  ('hadoop', 228),
#  ('innovation', 228),
#  ('physical', 228),
#  ('least', 228),
#  ('passionate', 228),
#  ('partners', 228),
#  ('dod', 228),
#  ('possible', 228),
#  ('units', 228),
#  ('locations', 227),
#  ('developers', 227),
#  ('two', 227),
#  ('local', 227),
#  ('built', 225),
#  ('existing', 224),
#  ('life', 224),
#  ('leads', 223),
#  ('participate', 221),
#  ('seeking', 221),
#  ('individuals', 218),
#  ('solve', 218),
#  ('committed', 218),
#  ('modeling', 217),
#  ('insights', 216),
#  ('requires', 216),
#  ('training', 215),
#  ('university', 215),
#  ('designs', 215),
#  ('reports', 214),
#  ('growing', 214),
#  ('growth', 213),
#  ('establish', 213),
#  ('addition', 212),
#  ('offer', 212),
#  ('commercial', 211),
#  ('communicate', 210),
#  ('ideas', 210),
#  ('care', 209),
#  ('writing', 208),
#  ('delivering', 208),
#  ('familiarity', 208),
#  ('mechanical', 208),
#  ('mobile', 207),
#  ('scientific', 207),
#  ('community', 206),
#  ('next', 205),
#  ('used', 205),
#  ('action', 204),
#  ('candidates', 204),
#  ('order', 202),
#  ('client', 201),
#  ('focus', 200),
#  ('considered', 199),
#  ('keep', 199),
#  ('produce', 198),
#  ('areas', 197),
#  ('open', 197),
#  ('small', 196),
#  ('sources', 196),
#  ('handson', 196),
#  ('occasionally', 196),
#  ('partner', 195),
#  ('love', 195),
#  ('functions', 194),
#  ('generation', 193),
#  ('external', 193),
#  ('laboratory', 193),
#  ('environments', 192),
#  ('obtain', 192),
#  ('realtime', 191),
#  ('essential', 191),
#  ('clean', 191),
#  ('quickly', 190),
#  ('frameworks', 187),
#  ('minority', 187),
#  ('tasks', 187),
#  ('know', 187),
#  ('grow', 187),
#  ('enterprise', 186),
#  ('computing', 186),
#  ('agency', 186),
#  ('javascript', 185),
#  ('desired', 185),
#  ('end', 184),
#  ('devices', 184),
#  ('verification', 184),
#  ('backgrounds', 184),
#  ('accredited', 183),
#  ('common', 183),
#  ('regular', 183),
#  ('continuous', 182),
#  ('companies', 182),
#  ('school', 182),
#  ('instruments', 182),
#  ('positive', 181),
#  ('azure', 180),
#  ('expert', 180),
#  ('fastpaced', 179),
#  ('regard', 179),
#  ('interface', 179),
#  ('applicable', 178),
#  ('competitive', 178),
#  ('imaging', 178),
#  ('higher', 178),
#  ('whether', 178),
#  ('reasonable', 178),
#  ('modern', 177),
#  ('millions', 177),
#  ('review', 175),
#  ('operational', 175),
#  ('sales', 174),
#  ('talented', 174),
#  ('things', 174),
#  ('full', 173),
#  ('female', 173),
#  ('contributing', 173),
#  ('stakeholders', 172),
#  ('making', 172),
#  ('record', 171),
#  ('automated', 171),
#  ('veterans', 171),
#  ('track', 170),
#  ('creative', 169),
#  ('marital', 169),
#  ('top', 169),
#  ('optimization', 168),
#  ('coding', 168),
#  ('deployment', 168),
#  ('write', 168),
#  ('fast', 168),
#  ('driving', 168),
#  ('efforts', 167),
#  ('managing', 167),
#  ('career', 167),
#  ('san', 167),
#  ('backend', 167),
#  ('interfaces', 167),
#  ('reviews', 167),
#  ('perspectives', 167),
#  ('demand', 167),
#  ('capabilities', 166),
#  ('change', 165),
#  ('supporting', 165),
#  ('search', 164),
#  ('operating', 163),
#  ('college', 163),
#  ('unique', 162),
#  ('define', 162),
#  ('sets', 162),
#  ('applicant', 162),
#  ('ie', 162),
#  ('principles', 161),
#  ('etl', 161),
#  ('proficiency', 161),
#  ('specifications', 160),
#  ('strategy', 160),
#  ('cost', 160),
#  ('rf', 160),
#  ('experienced', 159),
#  ('specific', 158),
#  ('comfortable', 158),
#  ('sensors', 158),
#  ('contribute', 158),
#  ('safe', 158),
#  ('technicians', 158),
#  ('execution', 157),
#  ('different', 157),
#  ('centers', 157),
#  ('collaborative', 157),
#  ('accommodation', 157),
#  ('experts', 156),
#  ('provides', 156),
#  ('state', 156),
#  ('collaboration', 156),
#  ('recognized', 156),
#  ('eeo', 155),
#  ('room', 155),
#  ('structures', 154),
#  ('reporting', 154),
#  ('statement', 154),
#  ('components', 154),
#  ('drives', 153),
#  ('linux', 153),
#  ('driven', 152),
#  ('financial', 152),
#  ('architectures', 152),
#  ('leader', 151),
#  ('dynamic', 151),
#  ('ml', 151),
#  ('producing', 151),
#  ('reliability', 150),
#  ('stack', 150),
#  ('location', 149),
#  ('monitoring', 149),
#  ('content', 149),
#  ('summary', 148),
#  ('area', 147),
#  ('improvement', 147),
#  ('1', 147),
#  ('goals', 147),
#  ('facilities', 146),
#  ('eligible', 146),
#  ('solution', 146),
#  ('edge', 145),
#  ('pipeline', 144),
#  ('diversity', 144),
#  ('come', 144),
#  ('personal', 143),
#  ('methodologies', 143),
#  ('needed', 142),
#  ('solid', 142),
#  ('online', 142),
#  ('crossfunctional', 142),
#  ('frontend', 142),
#  ('many', 142),
#  ('100', 141),
#  ('visualization', 141),
#  ('government', 140),
#  ('risk', 140),
#  ('productive', 140),
#  ('alexa', 140),
#  ('documents', 139),
#  ('appropriate', 139),
#  ('clinical', 139),
#  ('consumer', 139),
#  ('manager', 139),
#  ('independently', 138),
#  ('plan', 138),
#  ('sensing', 138),
#  ('individual', 137),
#  ('ground', 137),
#  ('implementing', 137),
#  ('performed', 137),
#  ('video', 137),
#  ('maintenance', 136),
#  ('basis', 136),
#  ('scala', 136),
#  ('flexible', 136),
#  ('model', 135),
#  ('analysts', 135),
#  ('methods', 135),
#  ('apis', 135),
#  ('center', 135),
#  ('healthcare', 135),
#  ('set', 135),
#  ('general', 134),
#  ('right', 134),
#  ('challenging', 134),
#  ('resources', 134),
#  ('presentation', 134),
#  ('groups', 133),
#  ('embedded', 133),
#  ('largest', 133),
#  ('helped', 133),
#  ('imagery', 133),
#  ('universe', 133),
#  ('startup', 132),
#  ('receive', 132),
#  ('integrate', 131),
#  ('additional', 131),
#  ('real', 131),
#  ('similar', 131),
#  ('earth', 131),
#  ('social', 130),
#  ('designers', 130),
#  ('home', 130),
#  ('consideration', 130),
#  ('appropriately', 130),
#  ('maintaining', 130),
#  ('exploitation', 130),
#  ('disabled', 130),
#  ('transgender', 130),
#  ('youre', 129),
#  ('performing', 129),
#  ('commute', 129),
#  ('datasets', 128),
#  ('ancestry', 128),
#  ('floor', 128),
#  ('first', 128),
#  ('substitute', 128),
#  ('insurance', 127),
#  ('tech', 127),
#  ('organizations', 127),
#  ('direct', 127),
#  ('media', 127),
#  ('microwave', 127),
#  ('transform', 127),
#  ('3000', 127),
#  ('nation', 127),
#  ('wide', 126),
#  ('clear', 126),
#  ('includes', 126),
#  ('detailed', 126),
#  ('execute', 126),
#  ('unit', 126),
#  ('interpersonal', 126),
#  ('subsystem', 126),
#  ('campuses', 126),
#  ('broad', 125),
#  ('ownership', 125),
#  ('regardless', 125),
#  ('predictable', 125),
#  ('lesbian', 125),
#  ('gay', 125),
#  ('bisexual', 125),
#  ('prototype', 124),
#  ('statistical', 124),
#  ('law', 124),
#  ('supply', 124),
#  ('optical', 124),
#  ('compliance', 124),
#  ('artificial', 124),
#  ('achievements', 124),
#  ('focused', 123),
#  ('evaluate', 123),
#  ('place', 123),
#  ('range', 123),
#  ('expression', 123),
#  ('assist', 123),
#  ('potential', 123),
#  ('spawn', 123),
#  ('marketdriven', 123),
#  ('secretary', 123),
#  ('states', 122),
#  ('universefrom', 122),
#  ('pioneered', 122),
#  ('higherlevel', 122),
#  ('electronics', 122),
#  ('10', 121),
#  ('major', 121),
#  ('aspects', 121),
#  ('directly', 121),
#  ('hands', 121),
#  ('limited', 120),
#  ('questions', 119),
#  ('human', 119),
#  ('scripting', 119),
#  ('rapidly', 119),
#  ('lieu', 119),
#  ('mentor', 118),
#  ('federal', 118),
#  ('proud', 117),
#  ('advertising', 117),
#  ('tests', 117),
#  ('nonball', 117),
#  ('fundamentals', 116),
#  ('abilities', 116),
#  ('validation', 116),
#  ('relational', 116),
#  ('developer', 116),
#  ('lifecycle', 116),
#  ('oriented', 116),
#  ('r', 115),
#  ('present', 115),
#  ('architect', 115),
#  ('largescale', 115),
#  ('4', 115),
#  ('cutting', 115),
#  ('standard', 115),
#  ('worldclass', 114),
#  ('discipline', 114),
#  ('retail', 114),
#  ('electronic', 114),
#  ('ecommerce', 114),
#  ('find', 113),
#  ('check', 113),
#  ('safety', 113),
#  ('feedback', 113),
#  ('domain', 113),
#  ('desire', 112),
#  ('motivated', 112),
#  ('levels', 112),
#  ('approach', 112),
#  ('nosql', 112),
#  ('natural', 112),
#  ('type', 112),
#  ('ways', 112),
#  ('fulltime', 111),
#  ('public', 111),
#  ('latest', 111),
#  ('scientist', 111),
#  ('works', 111),
#  ('successfully', 111),
#  ('optimize', 111),
#  ('storage', 110),
#  ('family', 110),
#  ('paid', 110),
#  ('genetic', 110),
#  ('ideal', 110),
#  ('weather', 110),
#  ('walmart', 110),
#  ('approaches', 109),
#  ('enjoy', 109),
#  ('responsibility', 109),
#  ('interest', 109),
#  ('protective', 109),
#  ('leveraging', 109),
#  ('united', 108),
#  ('deploy', 108),
#  ('manner', 108),
#  ('member', 108),
#  ('thrive', 108),
#  ('workplace', 107),
#  ('efficient', 105),
#  ('metrics', 105),
#  ('report', 105),
#  ('materials', 105),
#  ('detail', 105),
#  ('via', 105),
#  ('move', 105),
#  ('outdoors', 105),
#  ('document', 104),
#  ('leverage', 104),
#  ('email', 104),
#  ('chain', 103),
#  ('require', 103),
#  ('cuttingedge', 103),
#  ('gear', 103),
#  ('thinking', 102),
#  ('handle', 102),
#  ('flow', 102),
#  ('would', 101),
#  ('excited', 101),
#  ('configuration', 101),
#  ('subsystems', 101),
#  ('outside', 100),
#  ('robust', 100),
#  ('cycle', 100),
#  ('cancer', 100),
#  ('events', 100),
#  ('resumes', 100),
#  ('guidance', 99),
#  ('initiatives', 99),
#  ('believe', 99),
#  ('leaders', 98),
#  ('currently', 98),
#  ('applied', 98),
#  ('asml', 98),
#  ('consistent', 97),
#  ('changing', 97),
#  ('troubleshooting', 97),
#  ('seattle', 97),
#  ('statistics', 96),
#  ('dental', 96),
#  ('mathematics', 96),
#  ('researchers', 96),
#  ('operation', 96),
#  ('class', 96),
#  ('401k', 95),
#  ('improving', 95),
#  ('novel', 95),
#  ('request', 95),
#  ('visit', 94),
#  ('hiring', 94),
#  ('defining', 94),
#  ('values', 94),
#  ('lives', 94),
#  ('consider', 94),
#  ('excellence', 94),
#  ('peers', 94),
#  ('throughout', 94),
#  ('thermal', 94),
#  ('capable', 93),
#  ('docker', 93),
#  ('signal', 93),
#  ('8', 93),
#  ('desirable', 93),
#  ('assigned', 92),
#  ('primary', 92),
#  ('opportunityaffirmative', 92),
#  ('made', 92),
#  ('complete', 92),
#  ('devops', 92),
#  ('guide', 91),
#  ('device', 91),
#  ('investigation', 91),
#  ('daily', 91),
#  ('connect', 91),
#  ('leave', 91),
#  ('ecosystem', 90),
#  ('junior', 90),
#  ('difference', 90),
#  ('talent', 90),
#  ('deliverables', 90),
#  ('smart', 90),
#  ('prepare', 90),
#  ('builds', 90),
#  ('strategies', 90),
#  ('networks', 90),
#  ('completed', 90),
#  ('forward', 90),
#  ('fun', 89),
#  ('disciplines', 89),
#  ('scalability', 89),
#  ('oral', 89),
#  ('patterns', 89),
#  ('quantitative', 88),
#  ('extensive', 88),
#  ('finance', 88),
#  ('optimizing', 88),
#  ('matlab', 88),
#  ('physics', 88),
#  ('demands', 88),
#  ('controls', 88),
#  ('handling', 87),
#  ('7', 87),
#  ('go', 87),
#  ('creation', 87),
#  ('kafka', 87),
#  ('agencies', 87),
#  ('translate', 87),
#  ('hive', 87),
#  ('analyses', 87),
#  ('hire', 87),
#  ('protocols', 87),
#  ('energy', 87),
#  ('share', 87),
#  ('important', 86),
#  ('functionality', 86),
#  ('hours', 86),
#  ('architects', 85),
#  ('assurance', 85),
#  ('bonus', 85),
#  ('collection', 85),
#  ('framework', 85),
#  ('algorithm', 85),
#  ('sophisticated', 85),
#  ('reach', 85),
#  ('euv', 85),
#  ('businesses', 84),
#  ('objectives', 84),
#  ('completion', 84),
#  ('api', 84),
#  ('computational', 84),
#  ('legal', 84),
#  ('reliable', 84),
#  ('assistance', 84),
#  ('however', 84),
#  ('recruiting', 84),
#  ('exceptional', 83),
#  ('improvements', 83),
#  ('site', 83),
#  ('active', 83),
#  ('person', 83),
#  ('overall', 83),
#  ('excel', 83),
#  ('serve', 83),
#  ('communications', 83),
#  ('diego', 83),
#  ('professionals', 82),
#  ('offices', 82),
#  ('custom', 82),
#  ('interested', 82),
#  ('significant', 82),
#  ('presentations', 82),
#  ('lab', 82),
#  ('machines', 82),
#  ('ruby', 82),
#  ('experiments', 82),
#  ('live', 82),
#  ('applying', 81),
#  ('datadriven', 81),
#  ('endtoend', 81),
#  ('policy', 81),
#  ('6', 81),
#  ('extended', 81),
#  ('eligibility', 81),
#  ('prioritize', 81),
#  ('play', 80),
#  ('organizational', 80),
#  ('monitor', 80),
#  ('international', 80),
#  ('architectural', 80),
#  ('environmental', 80),
#  ('read', 80),
#  ('shopping', 80),
#  ('mentoring', 79),
#  ('consulting', 79),
#  ('comprehensive', 79),
#  ('priorities', 79),
#  ('criminal', 79),
#  ('massive', 79),
#  ('medicine', 79),
#  ('image', 79),
#  ('brands', 79),
#  ('intelligent', 79),
#  ('cc', 79),
#  ('suppliers', 79),
#  ('scaling', 79),
#  ('redshift', 79),
#  ('hard', 79),
#  ('close', 79),
#  ('dedicated', 78),
#  ('another', 78),
#  ('disabilities', 78),
#  ('low', 78),
#  ('prior', 78),
#  ('modules', 78),
#  ('concept', 78),
#  ('analyzing', 77),
#  ('coordinate', 77),
#  ('previous', 77),
#  ('decision', 77),
#  ('package', 77),
#  ('cross', 77),
#  ('benefit', 77),
#  ('roadmap', 77),
#  ('component', 77),
#  ('meetings', 77),
#  ('options', 76),
#  ('supports', 76),
#  ('secure', 76),
#  ('compensation', 76),
#  ('continue', 76),
#  ('influence', 76),
#  ('goal', 76),
#  ('subject', 76),
#  ('done', 76),
#  ('policies', 76),
#  ('interpret', 76),
#  ('studies', 75),
#  ('timely', 75),
#  ('offers', 75),
#  ('regulations', 75),
#  ('rest', 75),
#  ('due', 75),
#  ('multidisciplinary', 75),
#  ('capability', 75),
#  ('internet', 75),
#  ('cloudbased', 75),
#  ('determine', 74),
#  ('scope', 74),
#  ('feel', 74),
#  ('several', 74),
#  ('interaction', 74),
#  ('mental', 74),
#  ('pregnancy', 74),
#  ('collaborating', 74),
#  ('hundreds', 74),
#  ('attention', 74),
#  ('transformation', 74),
#  ('feature', 74),
#  ('advance', 74),
#  ('audiences', 74),
#  ('networking', 74),
#  ('react', 74),
#  ('noise', 74),
#  ('amazing', 73),
#  ('generate', 73),
#  ('conduct', 73),
#  ('efficiency', 73),
#  ('git', 73),
#  ('political', 73),
#  ('portfolio', 73),
#  ('light', 73),
#  ('developed', 73),
#  ('billions', 73),
#  ('definition', 73),
#  ('boston', 73),
#  ('think', 73),
#  ('salary', 72),
#  ('recommendations', 72),
#  ('sense', 72),
#  ('performs', 72),
#  ('demonstrate', 72),
#  ('release', 72),
#  ('availability', 72),
#  ('direction', 72),
#  ('deadlines', 72),
#  ('classified', 72),
#  ('detector', 72),
#  ('warehouse', 71),
#  ('transfer', 71),
#  ('windows', 71),
#  ...]

# %% [markdown]
# ### Other

# %%
## merge all the description together in one variable
other_descrip = ""
for descrip in ot['description']:
    other_descrip += " " + descrip

## import english stop_words (I, am, in, the...)
from nltk.corpus import stopwords
extra_stopword = ['data','experience','work','team','will','skill','year','skills']
stop_words1 = set((stopwords.words('english')))
stop_words = stop_words1.union(extra_stopword)

## transform the description in a tokenized list of words
from nltk.tokenize import word_tokenize
other_descrip_low= other_descrip.lower()
tokens = word_tokenize(str(other_descrip_low))

## count the frequency of witch tokenized word (without stop_words)
filtered_descrip_other = []
for word in tokens:
    if word not in list(stop_words):
        filtered_descrip_other += [word]
        
from collections import Counter
Counter(filtered_descrip_other).most_common()
# Out:
# [('research', 4219),
#  ('development', 3313),
#  ('ability', 2977),
#  ('management', 2835),
#  ('business', 2533),
#  ('including', 2523),
#  ('clinical', 2404),
#  ('product', 2278),
#  ('new', 2255),
#  ('required', 2244),
#  ('years', 2211),
#  ('support', 2172),
#  ('working', 2007),
#  ('technical', 1901),
#  ('information', 1833),
#  ('related', 1737),
#  ('design', 1735),
#  ('position', 1730),
#  ('teams', 1713),
#  ('degree', 1712),
#  ('scientists', 1689),
#  ('environment', 1689),
#  ('knowledge', 1637),
#  ('strong', 1627),
#  ('qualifications', 1558),
#  ('must', 1556),
#  ('requirements', 1552),
#  ('project', 1536),
#  ('opportunity', 1512),
#  ('medical', 1494),
#  ('science', 1478),
#  ('health', 1466),
#  ('analysis', 1458),
#  ('develop', 1448),
#  ('technology', 1448),
#  ('status', 1445),
#  ('software', 1403),
#  ('systems', 1337),
#  ('provide', 1337),
#  ('program', 1335),
#  ('products', 1333),
#  ('projects', 1333),
#  ('communication', 1323),
#  ('solutions', 1315),
#  ('responsibilities', 1299),
#  ('us', 1282),
#  ('preferred', 1276),
#  ('company', 1239),
#  ('within', 1236),
#  ('process', 1229),
#  ('customer', 1221),
#  ('amp', 1206),
#  ('programs', 1187),
#  ('job', 1183),
#  ('across', 1174),
#  ('well', 1172),
#  ('andor', 1154),
#  ('staff', 1113),
#  ('role', 1112),
#  ('engineering', 1096),
#  ('people', 1073),
#  ('responsible', 1064),
#  ('services', 1064),
#  ('may', 1064),
#  ('quality', 1049),
#  ('equal', 1044),
#  ('ensure', 1038),
#  ('lead', 1018),
#  ('excellent', 1012),
#  ('employment', 1006),
#  ('maintain', 996),
#  ('scientific', 968),
#  ('understanding', 967),
#  ('field', 964),
#  ('help', 960),
#  ('manage', 960),
#  ('employer', 951),
#  ('marketing', 946),
#  ('using', 944),
#  ('customers', 944),
#  ('key', 939),
#  ('operations', 930),
#  ('organization', 928),
#  ('national', 918),
#  ('laboratory', 915),
#  ('time', 910),
#  ('leadership', 909),
#  ('reports', 885),
#  ('build', 882),
#  ('engineers', 879),
#  ('education', 866),
#  ('tools', 864),
#  ('center', 862),
#  ('department', 859),
#  ('able', 854),
#  ('sales', 849),
#  ('internal', 847),
#  ('candidate', 844),
#  ('include', 843),
#  ('industry', 843),
#  ('written', 842),
#  ('complex', 839),
#  ('disability', 829),
#  ('study', 826),
#  ('needs', 824),
#  ('office', 823),
#  ('learning', 823),
#  ('high', 823),
#  ('global', 822),
#  ('computer', 816),
#  ('activities', 814),
#  ('training', 814),
#  ('use', 812),
#  ('system', 811),
#  ('one', 811),
#  ('results', 810),
#  ('clients', 809),
#  ('security', 803),
#  ('perform', 799),
#  ('make', 798),
#  ('also', 795),
#  ('gender', 791),
#  ('multiple', 783),
#  ('statistical', 778),
#  ('cancer', 776),
#  ('drive', 773),
#  ('service', 772),
#  ('procedures', 771),
#  ('developing', 768),
#  ('please', 764),
#  ('youll', 763),
#  ('minimum', 757),
#  ('strategy', 750),
#  ('applications', 744),
#  ('processes', 742),
#  ('appropriate', 740),
#  ('duties', 738),
#  ('based', 734),
#  ('performance', 728),
#  ('technologies', 727),
#  ('strategic', 726),
#  ('manager', 710),
#  ('world', 708),
#  ('care', 708),
#  ('analytics', 705),
#  ('highly', 702),
#  ('senior', 697),
#  ('identify', 695),
#  ('medicine', 694),
#  ('building', 693),
#  ('planning', 689),
#  ('external', 682),
#  ('best', 680),
#  ('level', 673),
#  ('create', 673),
#  ('professional', 672),
#  ('problems', 669),
#  ('orientation', 665),
#  ('part', 664),
#  ('demonstrated', 660),
#  ('effectively', 658),
#  ('client', 657),
#  ('successful', 657),
#  ('review', 656),
#  ('issues', 656),
#  ('expertise', 651),
#  ('employees', 647),
#  ('relevant', 647),
#  ('protected', 641),
#  ('need', 640),
#  ('benefits', 640),
#  ('bachelors', 638),
#  ('innovative', 635),
#  ('opportunities', 635),
#  ('biology', 631),
#  ('regulatory', 626),
#  ('diverse', 625),
#  ('leading', 623),
#  ('application', 623),
#  ('apply', 621),
#  ('applicants', 621),
#  ('looking', 614),
#  ('safety', 614),
#  ('color', 610),
#  ('sexual', 610),
#  ('human', 610),
#  ('assist', 608),
#  ('race', 607),
#  ('etc', 606),
#  ('veteran', 605),
#  ('culture', 602),
#  ('candidates', 600),
#  ('qualified', 594),
#  ('origin', 594),
#  ('plans', 593),
#  ('identity', 591),
#  ('studies', 588),
#  ('group', 587),
#  ('testing', 585),
#  ('religion', 585),
#  ('director', 580),
#  ('communicate', 577),
#  ('programming', 573),
#  ('relationships', 570),
#  ('provides', 568),
#  ('digital', 565),
#  ('plan', 565),
#  ('impact', 564),
#  ('mission', 563),
#  ('2', 562),
#  ('success', 562),
#  ('needed', 558),
#  ('documents', 555),
#  ('test', 554),
#  ('committed', 554),
#  ('employee', 550),
#  ('equipment', 548),
#  ('managers', 547),
#  ('advanced', 546),
#  ('join', 545),
#  ('compliance', 545),
#  ('plus', 540),
#  ('techniques', 540),
#  ('school', 536),
#  ('cell', 534),
#  ('vision', 533),
#  ('reporting', 532),
#  ('drug', 532),
#  ('managing', 528),
#  ('lab', 527),
#  ('improve', 520),
#  ('goals', 518),
#  ('meet', 515),
#  ('resources', 514),
#  ('closely', 513),
#  ('partners', 513),
#  ('effective', 513),
#  ('basic', 513),
#  ('machine', 512),
#  ('action', 512),
#  ('life', 510),
#  ('equivalent', 508),
#  ('patients', 507),
#  ('university', 507),
#  ('understand', 507),
#  ('deliver', 505),
#  ('growth', 504),
#  ('travel', 503),
#  ('individuals', 502),
#  ('area', 500),
#  ('public', 498),
#  ('without', 497),
#  ('sex', 497),
#  ('market', 496),
#  ('analytical', 496),
#  ('record', 496),
#  ('federal', 494),
#  ('eg', 492),
#  ('practices', 488),
#  ('members', 487),
#  ('microsoft', 487),
#  ('age', 486),
#  ('platform', 484),
#  ('various', 484),
#  ('patient', 484),
#  ('variety', 483),
#  ('areas', 481),
#  ('good', 481),
#  ('strategies', 479),
#  ('media', 479),
#  ('background', 477),
#  ('user', 474),
#  ('5', 473),
#  ('providing', 470),
#  ('independently', 468),
#  ('individual', 468),
#  ('methods', 467),
#  ('proven', 466),
#  ('documentation', 465),
#  ('collaborate', 464),
#  ('community', 462),
#  ('meetings', 460),
#  ('organizational', 457),
#  ('standards', 457),
#  ('learn', 456),
#  ('3', 452),
#  ('recruiting', 452),
#  ('assigned', 448),
#  ('policies', 444),
#  ('social', 443),
#  ('large', 443),
#  ('google', 442),
#  ('focus', 441),
#  ('1', 438),
#  ('necessary', 436),
#  ('delivery', 435),
#  ('writing', 435),
#  ('financial', 435),
#  ('implementation', 433),
#  ('execution', 433),
#  ('others', 433),
#  ('take', 432),
#  ('general', 428),
#  ('tasks', 428),
#  ('stakeholders', 425),
#  ('insights', 424),
#  ('partner', 423),
#  ('content', 423),
#  ('genetic', 422),
#  ('primary', 422),
#  ('around', 421),
#  ('verbal', 420),
#  ('models', 418),
#  ('value', 410),
#  ('seeking', 409),
#  ('creative', 408),
#  ('collaboration', 408),
#  ('conduct', 407),
#  ('challenges', 405),
#  ('track', 402),
#  ('regard', 401),
#  ('career', 400),
#  ('environmental', 398),
#  ('materials', 397),
#  ('discovery', 395),
#  ('web', 394),
#  ('leader', 394),
#  ('molecular', 394),
#  ('functions', 390),
#  ('every', 390),
#  ('access', 389),
#  ('trials', 389),
#  ('masters', 387),
#  ('institute', 384),
#  ('day', 384),
#  ('specific', 383),
#  ('critical', 382),
#  ('functional', 382),
#  ('innovation', 381),
#  ('current', 374),
#  ('levels', 371),
#  ('policy', 370),
#  ('applicable', 367),
#  ('production', 367),
#  ('detail', 366),
#  ('collaborative', 365),
#  ('agency', 364),
#  ('least', 362),
#  ('requires', 362),
#  ('nyu', 360),
#  ('network', 359),
#  ('used', 359),
#  ('organizations', 358),
#  ('competitive', 358),
#  ('big', 358),
#  ('attention', 358),
#  ('achieve', 357),
#  ('physical', 357),
#  ('execute', 357),
#  ('following', 356),
#  ('analyze', 355),
#  ('contribute', 354),
#  ('order', 354),
#  ('core', 353),
#  ('decisions', 352),
#  ('communications', 352),
#  ('protocols', 352),
#  ('fastpaced', 351),
#  ('control', 351),
#  ('better', 349),
#  ('experiences', 349),
#  ('direct', 348),
#  ('interpersonal', 346),
#  ('report', 346),
#  ('consideration', 345),
#  ('basis', 345),
#  ('database', 344),
#  ('existing', 344),
#  ('implement', 343),
#  ('creating', 341),
#  ('participate', 341),
#  ('essential', 341),
#  ('disease', 340),
#  ('healthcare', 340),
#  ('intelligence', 338),
#  ('making', 338),
#  ('marital', 337),
#  ('local', 337),
#  ('online', 335),
#  ('deep', 335),
#  ('diversity', 334),
#  ('professionals', 332),
#  ('state', 332),
#  ('sciences', 332),
#  ('statistics', 332),
#  ('leaders', 330),
#  ('future', 330),
#  ('works', 329),
#  ('summary', 329),
#  ('quantitative', 329),
#  ('phd', 328),
#  ('efforts', 327),
#  ('monitoring', 327),
#  ('processing', 326),
#  ('receive', 326),
#  ('serve', 326),
#  ('excel', 325),
#  ('potential', 323),
#  ('bring', 323),
#  ('ideas', 323),
#  ('define', 323),
#  ('additional', 322),
#  ('initiatives', 322),
#  ('focused', 321),
#  ('maintains', 321),
#  ('coordinate', 321),
#  ('great', 320),
#  ('schedule', 320),
#  ('way', 320),
#  ('manufacturing', 320),
#  ('oral', 319),
#  ('academic', 319),
#  ('locations', 319),
#  ('familiarity', 319),
#  ('supporting', 318),
#  ('change', 317),
#  ('san', 317),
#  ('users', 313),
#  ('growing', 313),
#  ('commercial', 312),
#  ('offer', 312),
#  ('associate', 312),
#  ('scientist', 311),
#  ('maintenance', 310),
#  ('diseases', 309),
#  ('available', 309),
#  ('uw', 309),
#  ('faculty', 308),
#  ('maintaining', 306),
#  ('broad', 305),
#  ('records', 305),
#  ('law', 304),
#  ('experiments', 304),
#  ('space', 302),
#  ('like', 300),
#  ('hospital', 299),
#  ('set', 298),
#  ('government', 297),
#  ('together', 297),
#  ('description', 297),
#  ('two', 296),
#  ('aerospace', 296),
#  ('preparation', 295),
#  ('proficiency', 295),
#  ('standard', 295),
#  ('risk', 295),
#  ('infrastructure', 293),
#  ('range', 292),
#  ('analyses', 292),
#  ('novel', 292),
#  ('experts', 291),
#  ('overall', 290),
#  ('includes', 290),
#  ('problem', 289),
#  ('agencies', 288),
#  ('groups', 288),
#  ('helping', 287),
#  ('ensuring', 286),
#  ('direction', 284),
#  ('approach', 284),
#  ('eeo', 284),
#  ('expression', 283),
#  ('events', 282),
#  ('enterprise', 282),
#  ('presentations', 282),
#  ('solve', 282),
#  ('worlds', 281),
#  ('cloud', 281),
#  ('solving', 281),
#  ('objectives', 281),
#  ('aspects', 279),
#  ('10', 279),
#  ('crossfunctional', 279),
#  ('administrative', 279),
#  ('dynamic', 278),
#  ('full', 278),
#  ('location', 278),
#  ('addition', 278),
#  ('computational', 278),
#  ('passion', 277),
#  ('practice', 277),
#  ('supervision', 277),
#  ('architecture', 276),
#  ('operational', 276),
#  ('consulting', 276),
#  ('sas', 276),
#  ('questions', 276),
#  ('regulations', 276),
#  ('delivering', 275),
#  ('international', 275),
#  ('biological', 275),
#  ('scale', 274),
#  ('hiring', 273),
#  ('interact', 272),
#  ('prior', 272),
#  ('proud', 271),
#  ('capabilities', 271),
#  ('expert', 271),
#  ('veterans', 271),
#  ('researchers', 271),
#  ('timely', 271),
#  ('member', 270),
#  ('fulltime', 270),
#  ('first', 269),
#  ('administration', 269),
#  ('small', 269),
#  ('regular', 269),
#  ('directly', 268),
#  ('college', 268),
#  ('translational', 268),
#  ('companies', 267),
#  ('right', 267),
#  ('place', 264),
#  ('generation', 264),
#  ('accommodation', 263),
#  ('platforms', 262),
#  ('setting', 262),
#  ('collection', 262),
#  ('insurance', 262),
#  ('complete', 261),
#  ('python', 261),
#  ('next', 261),
#  ('thinking', 260),
#  ('personnel', 260),
#  ('presentation', 259),
#  ('conditions', 259),
#  ('limited', 259),
#  ('modeling', 258),
#  ('ms', 258),
#  ('unique', 255),
#  ('desired', 255),
#  ('leads', 254),
#  ('code', 254),
#  ('decision', 254),
#  ('exciting', 254),
#  ('assistance', 253),
#  ('outstanding', 252),
#  ('affirmative', 252),
#  ('ways', 252),
#  ('metrics', 252),
#  ('visit', 251),
#  ('evaluation', 251),
#  ('three', 251),
#  ('trial', 250),
#  ('hours', 249),
#  ('present', 249),
#  ('portfolio', 248),
#  ('citizenship', 248),
#  ('prepare', 248),
#  ('contact', 247),
#  ('oncology', 247),
#  ('workplace', 246),
#  ('reviews', 246),
#  ('act', 246),
#  ('talent', 246),
#  ('approaches', 245),
#  ('manner', 245),
#  ('prioritize', 243),
#  ('performing', 242),
#  ('establish', 241),
#  ('site', 241),
#  ('person', 240),
#  ('responsibility', 238),
#  ('students', 238),
#  ('driven', 237),
#  ('document', 237),
#  ('request', 237),
#  ('comfortable', 237),
#  ('hardware', 237),
#  ('special', 237),
#  ('performs', 236),
#  ('electronic', 235),
#  ('reasonable', 235),
#  ('grow', 234),
#  ('4', 234),
#  ('ideal', 234),
#  ('experienced', 233),
#  ('clearance', 233),
#  ('designing', 232),
#  ('develops', 231),
#  ('account', 230),
#  ('require', 230),
#  ('exceptional', 228),
#  ('passionate', 227),
#  ('independent', 227),
#  ('different', 227),
#  ('get', 227),
#  ('commitment', 227),
#  ('major', 226),
#  ('fred', 226),
#  ('driving', 224),
#  ('ie', 224),
#  ('priorities', 224),
#  ('enable', 223),
#  ('concepts', 223),
#  ('offers', 223),
#  ('ongoing', 223),
#  ('therapeutic', 222),
#  ('positive', 222),
#  ('physicians', 222),
#  ('top', 221),
#  ('wide', 221),
#  ('amazon', 221),
#  ('family', 221),
#  ('corporate', 221),
#  ('open', 221),
#  ('power', 221),
#  ('throughout', 220),
#  ('resource', 220),
#  ('via', 219),
#  ('comprehensive', 219),
#  ('evaluate', 219),
#  ('language', 219),
#  ('improvement', 219),
#  ('view', 218),
#  ('subject', 218),
#  ('advertising', 217),
#  ('r', 216),
#  ('personal', 216),
#  ('guidance', 216),
#  ('quickly', 215),
#  ('budget', 215),
#  ('discipline', 215),
#  ('backgrounds', 215),
#  ('progress', 213),
#  ('word', 213),
#  ('analysts', 213),
#  ('ancestry', 213),
#  ('integrated', 213),
#  ('excellence', 212),
#  ('clear', 212),
#  ('coordinating', 212),
#  ('recommendations', 212),
#  ('early', 212),
#  ('implementing', 211),
#  ('experimental', 211),
#  ('multidisciplinary', 210),
#  ('pipeline', 210),
#  ('want', 210),
#  ('desire', 209),
#  ('roadmap', 209),
#  ('motivated', 209),
#  ('influence', 209),
#  ('construction', 209),
#  ('many', 208),
#  ('oversee', 208),
#  ('sql', 208),
#  ('principal', 208),
#  ('address', 208),
#  ('dedicated', 207),
#  ('monitor', 206),
#  ('type', 206),
#  ('integration', 205),
#  ('departments', 205),
#  ('overview', 204),
#  ('outside', 204),
#  ('feedback', 203),
#  ('offices', 203),
#  ('agile', 203),
#  ('databases', 202),
#  ('applying', 202),
#  ('lives', 202),
#  ('executive', 201),
#  ('consumer', 201),
#  ('know', 201),
#  ('possible', 201),
#  ('perspectives', 201),
#  ('sources', 200),
#  ('coordination', 200),
#  ('search', 200),
#  ('fast', 198),
#  ('consistent', 198),
#  ('prevention', 198),
#  ('sequencing', 198),
#  ('find', 198),
#  ('specifications', 198),
#  ('changes', 198),
#  ('ball', 198),
#  ('operating', 197),
#  ('successfully', 197),
#  ('due', 196),
#  ('compensation', 196),
#  ('centers', 196),
#  ('generate', 196),
#  ('significant', 196),
#  ('assays', 196),
#  ('expected', 195),
#  ('york', 195),
#  ('function', 195),
#  ('accurate', 195),
#  ('paid', 194),
#  ('recruitment', 194),
#  ('bioinformatics', 194),
#  ('startup', 193),
#  ('designers', 193),
#  ('interest', 193),
#  ('finance', 193),
#  ('model', 192),
#  ('package', 192),
#  ('engagement', 192),
#  ('initiative', 192),
#  ('assists', 192),
#  ('seattle', 192),
#  ('vendors', 191),
#  ('specialist', 190),
#  ('methodologies', 189),
#  ('keep', 189),
#  ('datasets', 189),
#  ('daily', 188),
#  ('laws', 188),
#  ('boston', 188),
#  ('usa', 187),
#  ('largest', 186),
#  ('requests', 186),
#  ('things', 186),
#  ('demonstrate', 186),
#  ('accounts', 186),
#  ('abilities', 185),
#  ('revenue', 184),
#  ('solution', 184),
#  ('langone', 184),
#  ('bs', 183),
#  ('detailed', 183),
#  ('handson', 182),
#  ('developers', 182),
#  ('colleagues', 182),
#  ('francisco', 182),
#  ('states', 182),
#  ('division', 182),
#  ('investigators', 182),
#  ('washington', 182),
#  ('pharmaceutical', 182),
#  ('regardless', 182),
#  ('accordance', 182),
#  ('resume', 181),
#  ('statement', 181),
#  ('accredited', 181),
#  ('trends', 181),
#  ('considered', 181),
#  ('regarding', 181),
#  ('samples', 181),
#  ('history', 181),
#  ('established', 181),
#  ('hire', 180),
#  ('annual', 180),
#  ('features', 180),
#  ('flexible', 180),
#  ('disabilities', 179),
#  ('guidelines', 179),
#  ('facilitate', 179),
#  ('outcomes', 179),
#  ('interpret', 179),
#  ('mobile', 178),
#  ('recognized', 178),
#  ('tests', 178),
#  ('chemistry', 178),
#  ('email', 178),
#  ('certification', 177),
#  ('changing', 177),
#  ('start', 177),
#  ('publications', 176),
#  ('desirable', 176),
#  ('facilities', 176),
#  ('manages', 176),
#  ('legal', 176),
#  ('firm', 175),
#  ('end', 175),
#  ('supply', 175),
#  ('routine', 175),
#  ('communities', 174),
#  ('currently', 174),
#  ('institution', 173),
#  ('city', 173),
#  ('deadlines', 173),
#  ('line', 173),
#  ('identifying', 172),
#  ('sets', 172),
#  ('unit', 172),
#  ('supports', 172),
#  ('military', 172),
#  ('treat', 172),
#  ('associated', 172),
#  ('talented', 172),
#  ('class', 172),
#  ('possess', 171),
#  ('previous', 171),
#  ('relationship', 171),
#  ('obtain', 171),
#  ('rapidly', 170),
#  ('political', 170),
#  ('click', 170),
#  ('contract', 170),
#  ('completion', 170),
#  ('home', 170),
#  ('letter', 169),
#  ('produce', 169),
#  ('determine', 168),
#  ('organized', 168),
#  ('hr', 168),
#  ('worldclass', 168),
#  ('goal', 168),
#  ('protocol', 168),
#  ('tracking', 168),
#  ('supplies', 167),
#  ('genetics', 167),
#  ('close', 166),
#  ('matter', 166),
#  ('acquisition', 166),
#  ('consider', 166),
#  ('date', 166),
#  ('audiences', 166),
#  ('leverage', 166),
#  ('salary', 165),
#  ('sites', 165),
#  ('therapeutics', 165),
#  ('common', 164),
#  ('6', 164),
#  ('ca', 164),
#  ('100', 163),
#  ('automation', 163),
#  ('deliverables', 163),
#  ('immunology', 163),
#  ('eligibility', 162),
#  ('follow', 162),
#  ('demand', 162),
#  ('thrive', 162),
#  ('dental', 162),
#  ('medicines', 162),
#  ('love', 161),
#  ('brand', 161),
#  ('values', 161),
#  ('advance', 161),
#  ('departmental', 161),
#  ('ensures', 161),
#  ('imaging', 161),
#  ('specialized', 160),
#  ('accuracy', 160),
#  ('send', 160),
#  ('edge', 160),
#  ('check', 160),
#  ('immune', 160),
#  ('cover', 159),
#  ('applicant', 159),
#  ('would', 159),
#  ('7', 158),
#  ('environments', 157),
#  ('real', 157),
#  ('continuous', 157),
#  ('share', 157),
#  ('material', 157),
#  ('interdisciplinary', 157),
#  ('form', 156),
#  ('point', 156),
#  ('built', 156),
#  ('forward', 156),
#  ('spacecraft', 156),
#  ('datadriven', 155),
#  ('performed', 155),
#  ('important', 155),
#  ('submit', 155),
#  ('input', 155),
#  ('facility', 155),
#  ('oversight', 155),
#  ('relocation', 155),
#  ('instruments', 155),
#  ('whether', 154),
#  ('tech', 154),
#  ('efficient', 154),
#  ('resumes', 154),
#  ('interface', 153),
#  ('screening', 153),
#  ('treatment', 153),
#  ('conducting', 153),
#  ('safe', 153),
#  ('assessment', 152),
#  ('meeting', 152),
#  ('pharmacology', 152),
#  ('per', 151),
#  ('cambridge', 151),
#  ('powerpoint', 151),
#  ('grant', 151),
#  ('forms', 151),
#  ('analyzing', 150),
#  ('designs', 150),
#  ('conferences', 150),
#  ('prepares', 150),
#  ('findings', 149),
#  ('units', 149),
#  ('think', 149),
#  ('preferably', 149),
#  ('cost', 149),
#  ('accounting', 149),
#  ('timelines', 148),
#  ('educational', 148),
#  ('tissue', 148),
#  ('response', 148),
#  ('genomics', 148),
#  ('actively', 147),
#  ('phone', 147),
#  ('principles', 147),
#  ('optimization', 147),
#  ('integrate', 147),
#  ('believe', 147),
#  ('engage', 147),
#  ('mental', 146),
#  ('criminal', 146),
#  ('resolve', 146),
#  ('made', 146),
#  ('completed', 146),
#  ('integrity', 146),
#  ('flow', 146),
#  ('benefit', 146),
#  ('applied', 146),
#  ('appropriately', 146),
#  ('source', 146),
#  ('targets', 145),
#  ('countries', 144),
#  ('united', 144),
#  ('collaboratively', 144),
#  ('computing', 144),
#  ('foundation', 143),
#  ('inc', 143),
#  ('handling', 143),
#  ('validation', 143),
#  ('shape', 143),
#  ('several', 142),
#  ('willingness', 142),
#  ('proposals', 142),
#  ('write', 142),
#  ('nature', 142),
#  ('course', 142),
#  ('rampd', 142),
#  ('ad', 142),
#  ('developer', 141),
#  ('characteristic', 141),
#  ('inventory', 141),
#  ('icf', 141),
#  ('difference', 141),
#  ('come', 141),
#  ('video', 141),
#  ('improving', 141),
#  ('womens', 141),
#  ('upon', 140),
#  ('contributing', 140),
#  ('retail', 140),
#  ('strongly', 140),
#  ('youre', 139),
#  ('cross', 139),
#  ('supervisor', 139),
#  ('schedules', 139),
#  ('operate', 139),
#  ('go', 139),
#  ('disciplines', 139),
#  ('worldwide', 139),
#  ('assistant', 139),
#  ('coordinates', 139),
#  ('protein', 139),
#  ('cells', 139),
#  ('lifecycle', 138),
#  ('encouraged', 138),
#  ('proficient', 138),
#  ('longterm', 138),
#  ('401k', 138),
#  ('encourage', 137),
#  ('harvard', 137),
#  ('days', 136),
#  ('partnership', 136),
#  ('energy', 136),
#  ('markets', 136),
#  ('shift', 135),
#  ('number', 135),
#  ('organize', 135),
#  ('roles', 135),
#  ('helped', 135),
#  ('competencies', 134),
#  ('institutions', 134),
#  ('according', 134),
#  ('creation', 134),
#  ('remote', 134),
#  ('nonprofit', 133),
#  ('assessments', 133),
#  ('challenging', 133),
#  ('monthly', 133),
#  ('judgment', 133),
#  ('investigator', 132),
#  ('2018', 132),
#  ('utilizing', 132),
#  ('enjoy', 132),
#  ('target', 132),
#  ('therapies', 132),
#  ...]
