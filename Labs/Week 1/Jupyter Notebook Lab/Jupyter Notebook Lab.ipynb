# %% [markdown]
# # 1. Introduction
#
# The purpose of this notebook is to introduce Pepe and his holidays preference with a picture and a link to a youtube video of this holiday preference.

# %%
# This function accepts input and returns it.
def name_selector(name):
    name = input("Write the person's name: ")
    return name
name_selector(name)
# Out:
# Write the person's name: Pepe
# 'Pepe'

# %% [markdown]
# Here's a picture of Pepe:
# ![](attachment:pepe.png)

# %%
# This function accepts input and returns it.
def holiday_preference(destination):
    destination = input('Where does Pepe want to travel to? ')
    return destination
holiday_preference(destination)
# Out:
# Where does Pepe want to travel to? North-East Queensland
# 'North-East Queensland'

# %% [markdown]
# Indeed, Pepe wants to go to North-East Queensland, Australia, to hang out with some of his frog mates. There are lots of them there!
#
# Here we can see the region on a map:
# ![queensland1.png](attachment:queensland1.png)

# %% [markdown]
# And here we can see some of Pepe's peers:
# ![queensland3.png](attachment:queensland3.png)

# %% [markdown]
# ### In North-East Queensland, Pepe likes to...
# ... swim in a **pond**
# ... catch some _flies_ with his tongue
# ... do <font color='green'>**frog stuff**</font>

# %% [markdown]
# [Here](https://www.youtube.com/watch?v=rm3hd1pxHME) you can see some of the action Pepe's looking forward to.
