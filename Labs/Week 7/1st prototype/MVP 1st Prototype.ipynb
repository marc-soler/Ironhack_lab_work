# %%
import pandas as pd
from top100 import *
from tkinter import *

# %%
# Creating the window
window = Tk()
window.title('Song Recommender')
window.minsize(width=500, height=300)
window.config(padx=20, pady=20)
# Creating a label
my_label = Label(text='Welcome to the Song Recommender!', font=('Arial', 24, 'bold'))
my_label.pack(side='left') #or place(x, y) or grid(column, row)
# Creating a button and making it interactive
def button_clicked():
    print('I was clicked')
button = Button(text='Click me', command=button_clicked)
button.pack()
# Entry field & getting the input
input = Entry(width=10)
input.pack()
print(input.get())
window.mainloop() # this always at the end to keep window running
# Out:
# I was clicked

# %%
top100()
# Out:
#     rank                       song_title  \
# 0      1        We Don't Talk About Bruno
# 1      2                       Heat Waves
# 2      3                          abcdefu
# 3      4                       Easy On Me
# 4      5                    Super Gremlin
# ..   ...                              ...
# 95    96                           Closer
# 96    97                    Cold December
# 97    98                Get Into It (Yuh)
# 98    99  All Too Well (Taylor's Version)
# 99   100            Give Heaven Some Hell
#
#                                               artists weeks_on_chart
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...              9
# 1                                       Glass Animals             58
# 2                                               GAYLE             14
# 3                                               Adele             20
# 4                                         Kodak Black             16
# ...
