# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Useful-functions" data-toc-modified-id="Useful-functions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Useful functions</a></span></li><li><span><a href="#File-description:" data-toc-modified-id="File-description:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>File description:</a></span><ul class="toc-item"><li><span><a href="#notes-to-return-to-later:" data-toc-modified-id="notes-to-return-to-later:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>notes to return to later:</a></span></li></ul></li><li><span><a href="#Merging-the-dataframes-with-concat():" data-toc-modified-id="Merging-the-dataframes-with-concat():-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Merging the dataframes with concat():</a></span></li><li><span><a href="#Basic-cleaning-of-the-dataframe:" data-toc-modified-id="Basic-cleaning-of-the-dataframe:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Basic cleaning of the dataframe:</a></span><ul class="toc-item"><li><span><a href="#Enhancing-the-data:" data-toc-modified-id="Enhancing-the-data:-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Enhancing the data:</a></span><ul class="toc-item"><li><span><a href="#Changing-the-headers-into-lower-case:" data-toc-modified-id="Changing-the-headers-into-lower-case:-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Changing the headers into lower case:</a></span></li><li><span><a href="#Drop-useless-columns:" data-toc-modified-id="Drop-useless-columns:-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Drop useless columns:</a></span></li><li><span><a href="#Renaming-columns-to-be-more-meaninful:" data-toc-modified-id="Renaming-columns-to-be-more-meaninful:-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Renaming columns to be more meaninful:</a></span></li><li><span><a href="#Looking-into-datatypes:" data-toc-modified-id="Looking-into-datatypes:-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Looking into datatypes:</a></span></li></ul></li><li><span><a href="#Searching-for-and-eliminating-duplicates:" data-toc-modified-id="Searching-for-and-eliminating-duplicates:-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Searching for and eliminating duplicates:</a></span></li></ul></li><li><span><a href="#Filter-and-query-data-in-a-dataframe:" data-toc-modified-id="Filter-and-query-data-in-a-dataframe:-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Filter and query data in a dataframe:</a></span></li><li><span><a href="#Extract-as-a-csv:" data-toc-modified-id="Extract-as-a-csv:-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Extract as a csv:</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('../data/file1.csv')
file2 = pd.read_csv('../data/file2.txt', sep='\t')
file3 = pd.read_excel('../data/file3.xlsx')
file4 = pd.read_excel('../data/file4.xlsx')

# %% [markdown]
# # Useful functions
# .value_counts()
# .unique()

# %% [markdown]
# # File description:

# %%
file1.describe()
# Out:
#             CONTROLN          IC1          IC4         HVP1        POBC1  \
# count    1007.000000  1007.000000  1006.000000  1007.000000  1007.000000
# mean    98913.029791   352.015889   445.059642    16.261172     6.847071
# std     58306.879885   173.937638   178.115476    29.464477     9.333689
# min        71.000000     0.000000     0.000000     0.000000     0.000000
# 25%     44930.500000   238.500000   325.000000     0.000000     1.000000
# 50%    101113.000000   319.000000   406.000000     1.000000     4.000000
# 75%    151559.000000   421.500000   527.000000    14.000000     9.000000
# max    191779.000000  1500.000000  1263.000000    99.000000    73.000000
#
#              POBC2          IC2          IC3      AVGGIFT        TCODE  \
# count  1007.000000  1006.000000  1007.000000  1007.000000  1007.000000
# mean     55.630586   401.658052   400.022840    11.863404    37.747766
# std      21.593999   182.024618   168.901139     7.829965   213.010617
# ...

# %%
file1.tail(10)
#check for fitness of index number at the end.
# Out:
#       CONTROLN STATE GENDER   HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 997      57151    KY      F   875  311  326.0     0   7746      3     29
# 998      71425    MI      M   713  300  364.0     0  16833      2     88
# 999     127823    TX      F   258   64   74.0     0   4236      0     94
# 1000    150739    CA      U  1951  556  625.0    44  17208     10     66
# 1001     41384    FL      F   556  318  352.0     0  11779     16     22
# 1002    114721    OK    NaN  1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M  4507  842  962.0    95  54642     17     50
# 1004       959    IA      F   586  349  465.0     1  15304      1     77
# 1005    179563    WA   male   842  420  494.0     2  12894     41     24
# 1006     41243    FL      F   556  246  330.0     0  10272      2     56
#
#          IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 997    326.0  326  15.900000      0  3601     R1      26.0
# ...

# %%
file2.tail(10)
# Out:
#       CONTROLN STATE  GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 1005    161726    CA       F  2453  438  475    86  15707     16     45  451
# 1006    125986    TX       M   533  246  308     1  10096      3     75  276
# 1007    185394    MI       F   647  285  338     0  12910      7     80  317
# 1008     43799    FL       F  1044  366  499    15  22427      8     35  318
# 1009    161838    CA       F  1953  304  380    47  13811     25     43  353
# 1010    161838    CA       F  1953  304  380    47  13811     25     43  353
# 1011    161838    CA       F  1953  304  380    47  13811     25     43  353
# 1012    138311    AZ  Female  1708  437  684    36  29098      7     19  586
# 1013    123469    TX       M   561  493  540     1  16623      5     68  529
# 1014    135341    AZ  Female   700  205  295     0  12713      9     12  221
#
#         IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 1005  436.0   5.812500      0  4601     T1       7.0
# ...

# %%
file2['GENDER'].unique()
# Out:
# array(['M', 'F', 'feamale', nan, 'U', 'Male', 'male', 'J', 'female',
#        'Female'], dtype=object)

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CONTROLN  1007 non-null   int64
#  1   STATE     1007 non-null   object
#  2   GENDER    967 non-null    object
#  3   HV1       1005 non-null   object
#  4   IC1       1007 non-null   int64
#  5   IC4       1006 non-null   float64
#  6   HVP1      1007 non-null   int64
#  7   IC5       1007 non-null   object
#  8   POBC1     1007 non-null   int64
#  9   POBC2     1007 non-null   int64
#  10  IC2       1006 non-null   float64
#  11  IC3       1007 non-null   int64
#  12  AVGGIFT   1007 non-null   float64
#  13  TCODE     1007 non-null   int64
#  14  DOB       1007 non-null   int64
#  15  DOMAIN    1007 non-null   object
#  16  TARGET_D  1007 non-null   float64
# dtypes: float64(4), int64(8), object(5)
# memory usage: 133.9+ KB

# %%
file2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CONTROLN  1015 non-null   int64
#  1   STATE     1015 non-null   object
#  2   GENDER    985 non-null    object
#  3   HV1       1015 non-null   int64
#  4   IC1       1015 non-null   int64
#  5   IC4       1015 non-null   int64
#  6   HVP1      1015 non-null   int64
#  7   IC5       1015 non-null   int64
#  8   POBC1     1015 non-null   int64
#  9   POBC2     1015 non-null   int64
#  10  IC2       1015 non-null   int64
#  11  IC3       1015 non-null   int64
#  12  AVGGIFT   1015 non-null   float64
#  13  TCODE     1015 non-null   int64
#  14  DOB       1015 non-null   int64
#  15  DOMAIN    1015 non-null   object
#  16  TARGET_D  1015 non-null   float64
# dtypes: float64(2), int64(12), object(3)
# memory usage: 134.9+ KB

# %%
file3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CONTROLN  1000 non-null   int64
#  1   STATE     1000 non-null   object
#  2   GENDER    964 non-null    object
#  3   HV1       1000 non-null   int64
#  4   IC1       1000 non-null   int64
#  5   IC4       1000 non-null   int64
#  6   HVP1      1000 non-null   int64
#  7   IC5       1000 non-null   int64
#  8   POBC1     1000 non-null   int64
#  9   POBC2     1000 non-null   int64
#  10  IC2       1000 non-null   int64
#  11  IC3       1000 non-null   int64
#  12  AVGGIFT   1000 non-null   float64
#  13  TCODE     1000 non-null   int64
#  14  DOB       1000 non-null   int64
#  15  DOMAIN    1000 non-null   object
#  16  TARGET_D  1000 non-null   float64
# dtypes: float64(2), int64(12), object(3)
# memory usage: 132.9+ KB

# %%
file4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CONTROLN  1006 non-null   int64
#  1   STATE     1006 non-null   object
#  2   GENDER    976 non-null    object
#  3   HV1       1006 non-null   object
#  4   IC1       1006 non-null   int64
#  5   IC4       1006 non-null   int64
#  6   HVP1      1006 non-null   int64
#  7   IC5       1006 non-null   int64
#  8   POBC1     1006 non-null   int64
#  9   POBC2     1006 non-null   int64
#  10  IC2       1006 non-null   int64
#  11  IC3       1006 non-null   int64
#  12  AVGGIFT   1006 non-null   float64
#  13  TCODE     1006 non-null   int64
#  14  DOB       1006 non-null   int64
#  15  DOMAIN    1006 non-null   object
#  16  TARGET_D  1006 non-null   float64
# dtypes: float64(2), int64(11), object(4)
# memory usage: 133.7+ KB

# %% [markdown]
# ## notes to return to later:
# - missing a lot of gender values
# - lots of zeroes showing in columns
# - dtypes discrepancies, especially in CONTROLN
# - occsasional missing values

# %% [markdown]
# # Merging the dataframes with concat():

# %%
data = pd.concat([file1, file2, file3, file4], axis=0, ignore_index=True)
#after doing concat or removing rows we need to reset the index. In this case, we did it in the concat function.
#the above is the same as .reset_index()

# %%
data
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 4023     41537    FL      F      742  396  470.0     0  15356      7     37
# 4024      4881    FL      M      599  100  423.0     4  11670     10     27
# 4025     66358    ND      M      593  258  299.0     0  10186      1     70
# 4026      2231    WI   male      564  217  397.0     0  12315      0     96
# 4027     68534    MI      M      651  431  505.0     0  14845      7     77
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4028 entries, 0 to 4027
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CONTROLN  4028 non-null   int64
#  1   STATE     4028 non-null   object
#  2   GENDER    3892 non-null   object
#  3   HV1       4026 non-null   object
#  4   IC1       4028 non-null   int64
#  5   IC4       4027 non-null   float64
#  6   HVP1      4028 non-null   int64
#  7   IC5       4028 non-null   object
#  8   POBC1     4028 non-null   int64
#  9   POBC2     4028 non-null   int64
#  10  IC2       4027 non-null   float64
#  11  IC3       4028 non-null   int64
#  12  AVGGIFT   4028 non-null   float64
#  13  TCODE     4028 non-null   int64
#  14  DOB       4028 non-null   int64
#  15  DOMAIN    4028 non-null   object
#  16  TARGET_D  4028 non-null   float64
# dtypes: float64(4), int64(8), object(5)
# memory usage: 535.1+ KB

# %% [markdown]
# # Basic cleaning of the dataframe:
# - Standardise the headers into lower case
# - Drop specified columns
# - Set the data types
# - Drop any duplicates
# - Deal with empty values
#
# ## Enhancing the data:
# - Rename the columns to be more meaningful
# - Bucket the values / standardise the labels

# %% [markdown]
# ### Changing the headers into lower case:

# %%
cols = []
for i in range(len(data.columns)):
    cols.append(data.columns[i].lower())
data.columns = cols
data.columns
# Out:
# Index(['controln', 'state', 'gender', 'hv1', 'ic1', 'ic4', 'hvp1', 'ic5',
#        'pobc1', 'pobc2', 'ic2', 'ic3', 'avggift', 'tcode', 'dob', 'domain',
#        'target_d'],
#       dtype='object')

# %% [markdown]
# ### Drop useless columns:

# %%
datanew = data.drop(['controln', 'pobc2'], axis = 1)

# %%
datanew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4028 entries, 0 to 4027
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     4028 non-null   object
#  1   gender    3892 non-null   object
#  2   hv1       4026 non-null   object
#  3   ic1       4028 non-null   int64
#  4   ic4       4027 non-null   float64
#  5   hvp1      4028 non-null   int64
#  6   ic5       4028 non-null   object
#  7   pobc1     4028 non-null   int64
#  8   ic2       4027 non-null   float64
#  9   ic3       4028 non-null   int64
#  10  avggift   4028 non-null   float64
#  11  tcode     4028 non-null   int64
#  12  dob       4028 non-null   int64
#  13  domain    4028 non-null   object
#  14  target_d  4028 non-null   float64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 472.2+ KB

# %% [markdown]
# ### Renaming columns to be more meaninful:

# %%
new_names = {
    'hv1': 'medianhv',
    'ic5': 'percapita',
}
data.rename(columns=new_names, inplace=True)
data.head()
# Out:
#    controln state gender medianhv  ic1    ic4  hvp1 percapita  pobc1  pobc2  \
# 0     44060    FL      M   AAA896  392  520.0     7     21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0     19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3     18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7     14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0     17991      5      6
#
#      ic2  ic3    avggift  tcode   dob domain  target_d
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %% [markdown]
# ### Looking into datatypes:
# - controln should be object
# - hv1 should be float
# - ic5 should be float
# - dob should be date

# %%
data.dtypes
# Out:
# Controln      int64
# State        object
# Gender       object
# Hv1          object
# Ic1           int64
# Ic4         float64
# Hvp1          int64
# Ic5          object
# Pobc1         int64
# Pobc2         int64
# Ic2         float64
# Ic3           int64
# Avggift     float64
# Tcode         int64
# Dob           int64
# Domain       object
# Target_D    float64
# dtype: object

# %%
data['medianhv'] = pd.to_numeric(data['medianhv'], errors='coerce')
data['percapita'] = pd.to_numeric(data['percapita'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4028 entries, 0 to 4027
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   controln   4028 non-null   int64
#  1   state      4028 non-null   object
#  2   gender     3892 non-null   object
#  3   medianhv   4018 non-null   float64
#  4   ic1        4028 non-null   int64
#  5   ic4        4027 non-null   float64
#  6   hvp1       4028 non-null   int64
#  7   percapita  4022 non-null   float64
#  8   pobc1      4028 non-null   int64
#  9   pobc2      4028 non-null   int64
#  10  ic2        4027 non-null   float64
#  11  ic3        4028 non-null   int64
#  12  avggift    4028 non-null   float64
#  13  tcode      4028 non-null   int64
#  14  dob        4028 non-null   int64
#  15  domain     4028 non-null   object
#  16  target_d   4028 non-null   float64
# dtypes: float64(6), int64(8), object(3)
# memory usage: 535.1+ KB

# %% [markdown]
# ## Searching for and eliminating duplicates:

# %%
data = data.drop_duplicates()
# without any arguments, it drops full duplicated rows.

# %% [markdown]
# # Filter and query data in a dataframe:

# %%
# Method 1: query
data.query('gender == "F" & state=="CA"')
# Out:
#       controln state gender  medianhv  ic1    ic4  hvp1  percapita  pobc1  \
# 8       173223    CA      F       NaN  184  250.0     0     8708.0      2
# 9       157988    CA      F       NaN  593  617.0    61    17838.0      7
# 11      186272    CA      F    3515.0  521  588.0    97    20068.0     11
# 36      154245    CA      F     596.0  164  190.0     0     5273.0     23
# 40       10145    CA      F    2362.0  613  678.0    74    21179.0      9
# ...        ...   ...    ...       ...  ...    ...   ...        ...    ...
# 3981    159721    CA      F     683.0  194  333.0     1    10267.0      9
# 4002    157826    CA      F    2387.0  394  447.0    76    17331.0     18
# 4004      4638    CA      F    2473.0  585  611.0    86    21343.0      4
# 4010    142600    CA      F     919.0   89  210.0     3     4825.0     41
# 4020    151175    CA      F    2707.0  507  537.0    80    16165.0     24
#
#       pobc2    ic2  ic3    avggift  tcode   dob domain  target_d
# ...

# %%
# Method 2: using tilde symbol ~ to do inverse filtering
female_genders = ['F', 'f', 'FEMALE','female', 'feamale']
data[~data.gender.isin(female_genders)]
# Out:
#       controln state gender  medianhv  ic1    ic4  hvp1  percapita  pobc1  \
# 0        44060    FL      M       NaN  392  520.0     7    21975.0      6
# 1        96093    IL      M     537.0  365  473.0     0    19387.0      1
# 3        21885    NC      M       NaN  401  413.0     7    14014.0      1
# 5       100640    IL      M     764.0  457  501.0     1    16022.0      2
# 7       119038    TX      M     890.0  519  560.0     0    17872.0      2
# ...        ...   ...    ...       ...  ...    ...   ...        ...    ...
# 4016     68618    MI      M     726.0  485  509.0     0    17020.0      3
# 4017      1646    CA      M     675.0  163  230.0     1     7083.0     13
# 4019      6443    FL      M     595.0  252  274.0     0    11132.0      8
# 4021    151504    CA      M    2666.0  535  653.0    63    24745.0     22
# 4022     74303    MI      M     444.0  225  299.0     3    10088.0      1
#
#       pobc2    ic2  ic3    avggift  tcode   dob domain  target_d
# ...

# %%
# Method 3: iloc (by index)
data.iloc[4:6] #plus rows, columns, lists as parameters
# Out:
#    controln state gender  medianhv  ic1    ic4  hvp1  percapita  pobc1  pobc2  \
# 4    190108    FL      F     995.0  252  348.0     0    17991.0      5      6
# 5    100640    IL      M     764.0  457  501.0     1    16022.0      2     75
#
#      ic2  ic3    avggift  tcode   dob domain  target_d
# 4  280.0  316   6.000000     28     0     C2       5.0
# 5  477.0  480  25.571429      1  6104     S2      30.0

# %%
# Method 4: loc (by name)
data.loc[data['gender'] == 'F']
# Out:
#       controln state gender  medianhv  ic1    ic4  hvp1  percapita  pobc1  \
# 2        43333    FL      F     725.0  301  436.0     3    18837.0     11
# 4       190108    FL      F     995.0  252  348.0     0    17991.0      5
# 8       173223    CA      F       NaN  184  250.0     0     8708.0      2
# 9       157988    CA      F       NaN  593  617.0    61    17838.0      7
# 10      141720    NV      F    1569.0  673  781.0    22    25775.0      3
# ...        ...   ...    ...       ...  ...    ...   ...        ...    ...
# 4011     26009    GA      F     899.0  396  501.0     1    15973.0      6
# 4013     77441    WI      F     725.0  316  376.0     0    11623.0      1
# 4015    117326    TX      F    1715.0  554  837.0    34    31480.0      3
# 4018     66762    MI      F     632.0  279  388.0     2    12653.0      1
# 4020    151175    CA      F    2707.0  507  537.0    80    16165.0     24
#
#       pobc2    ic2  ic3    avggift  tcode   dob domain  target_d
# ...

# %%
# Method 5: using brackets and criteria (allows to mix string and number filters)
data[(data['state']=='FL')&(data['gender']=='M')&(data['ic1']>300)]
# Out:
#       controln state gender  medianhv  ic1    ic4  hvp1  percapita  pobc1  \
# 0        44060    FL      M       NaN  392  520.0     7    21975.0      6
# 175      11494    FL      M    1229.0  469  544.0    21    17313.0      2
# 203      38820    FL      M    1332.0  357  497.0     2    21444.0     14
# 220     191779    FL      M    1432.0  636  772.0    24    35544.0      0
# 242      39479    FL      M    1287.0  479  616.0     7    20795.0     15
# ...        ...   ...    ...       ...  ...    ...   ...        ...    ...
# 3862     37575    FL      M    1938.0  400  606.0    50    34430.0     56
# 3904     40421    FL      M    1270.0  363  519.0    15    17548.0      8
# 3935     14552    FL      M    1518.0  449  523.0    26    17518.0     11
# 3984     36776    FL      M     653.0  319  379.0     0    12869.0     11
# 4014      6403    FL      M     677.0  311  313.0     0    12509.0      2
#
#       pobc2    ic2  ic3    avggift  tcode   dob domain  target_d
# ...

# %%
# Method 6: .filter()
data.filter(items=['state', 'gender'], axis=1)
# Out:
#      state gender
# 0       FL      M
# 1       IL      M
# 2       FL      F
# 3       NC      M
# 4       FL      F
# ...    ...    ...
# 4018    MI      F
# 4019    FL      M
# 4020    CA      F
# 4021    CA      M
# 4022    MI      M
#
# [4001 rows x 2 columns]

# %% [markdown]
# # Extract as a csv:

# %%
data.to_csv('../data/day1_analysis_H4A.csv', index=False)
